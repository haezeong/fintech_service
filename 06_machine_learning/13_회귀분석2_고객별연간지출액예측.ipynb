# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("./data/ecommerce.csv")
data
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# 495  4483 Jones Motorway Suite 872\nLake Jamiefurt,...               Tan
# 496  172 Owen Divide Suite 497\nWest Richard, CA 19320     PaleVioletRed
# 497  0787 Andrews Ranch Apt. 633\nSouth Chadburgh, ...          Cornsilk
# 498  680 Jennifer Lodge Apt. 808\nBrendachester, TX...              Teal
# 499  49791 Rachel Heights Apt. 898\nEast Drewboroug...       DarkMagenta
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
#      Yearly Amount Spent
# 0             587.951054
# 1             392.204933
# 2             487.547505
# 3             581.852344
# 4             599.406092
# ..                   ...
# 495           573.847438
# 496           529.049004
# 497           551.620145
# 498           456.469510
# 499           497.778642
#
# [500 rows x 8 columns]

# %% [markdown]
# Yearly Amount Spent:가격이라는 연속값 예측-> 회귀사용

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
data.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %% [markdown]
# Email : 고객의 이메일 주소 <br>
# Address : 고객이 사는 주소<br>
# Avatar : 고객의 아바타 캐릭터<br>
# Avb.Session Length : 고객의 접속한 시간의 평균<br>
# Time on App : 어플리케이션에서 사용한 시간<br>
# Time on Website : 웹 사이트에서 사용한 시간<br>
# Length of Membership : 고객의 맴버쉽 가입 기간<br>
# Yearly Amount Spent : 고객이 연간 쓴 금액<br>

# %%
data.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
sns.boxplot(data[['Avg. Session Length', 'Time on App',
       'Time on Website', 'Length of Membership', 'Yearly Amount Spent']])
# Out:
# <Axes: >

# %%
sns.boxplot(data[['Avg. Session Length', 'Time on App',
       'Time on Website', 'Length of Membership']])
# Out:
# <Axes: >

# %%
outlier = data.describe()

# %%
outlier
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
outlier.loc['75%']+ (1.5*(outlier.loc['75%']-outlier.loc['25%']))
# Out:
# Avg. Session Length      35.767230
# Time on App              14.802394
# Time on Website          39.767195
# Length of Membership      5.920580
# Yearly Amount Spent     705.727153
# dtype: float64

# %%
outlier.loc['25%']- (1.5*(outlier.loc['75%']-outlier.loc['25%']))
# Out:
# Avg. Session Length      30.286577
# Time on App               9.339609
# Time on Website          34.298495
# Length of Membership      1.136371
# Yearly Amount Spent     288.624951
# dtype: float64

# %%
data['Address'].nunique()
# Out:
# 500

# %%
data['Avatar'].nunique()
# Out:
# 138

# %%
data.groupby('Avatar')['Yearly Amount Spent'].mean()
# Out:
# Avatar
# AliceBlue       473.626376
# AntiqueWhite    465.943767
# Aqua            502.644032
# Aquamarine      444.797949
# Azure           452.627255
#                    ...
# Wheat           551.271616
# White           516.027238
# WhiteSmoke      524.142151
# Yellow          562.082045
# YellowGreen     460.693239
# Name: Yearly Amount Spent, Length: 138, dtype: float64

# %%
sorted(data.groupby('Avatar')['Yearly Amount Spent'].mean())
# Out:
# [386.6479469644702,
#  406.72210505413426,
#  419.63294156751954,
#  420.4525495603057,
#  425.7450920310528,
#  426.2491997948072,
#  430.6901723817928,
#  432.5880745084584,
#  434.0216997527185,
#  435.50696136042393,
#  435.53438736846255,
#  436.7205558562188,
#  436.93721042160973,
#  437.98836007828095,
#  441.0606890984435,
#  444.79794926582264,
#  449.6439355046467,
#  450.8085408678162,
#  452.62725499508304,
#  457.3757575535788,
#  457.84769594494855,
#  458.1109670290833,
#  459.73175574914313,
#  460.6932386153623,
#  464.4492715811856,
#  464.64799776409825,
#  465.219163427335,
#  465.94376701872335,
#  467.9852374676245,
#  469.89882388155974,
#  471.9477147236624,
#  472.1404800783187,
#  473.33094790940635,
#  473.62637580373496,
#  474.3145305571195,
#  475.2178389767011,
#  475.759067788328,
#  476.3801445434332,
#  476.7667241547634,
#  476.989533966875,
#  477.9051175131702,
#  478.33616628747586,
#  480.6720732687792,
#  481.0113949279279,
#  481.3977129840615,
#  482.5055820949065,
#  483.3034620257754,
#  483.40727367591916,
#  483.5028225299293,
#  483.5825070793288,
#  484.2295101925791,
#  484.5198091105512,
#  484.97371365644,
#  485.4708387975196,
#  488.3736590239255,
#  489.20351655833764,
#  489.4895796782257,
#  490.15197091900274,
#  490.9599242723951,
#  493.73274129345344,
#  494.55186108657256,
#  494.85966699476995,
#  495.05147850584444,
#  495.2865468163272,
#  496.32696318486444,
#  496.43981111201964,
#  496.9787070275205,
#  498.92407555345693,
#  500.8687862581053,
#  501.04242056826666,
#  501.2503549576529,
#  502.4039726944144,
#  502.4966582003473,
#  502.6440323918084,
#  502.85661618877293,
#  503.73773399413557,
#  505.2300682820706,
#  507.8263826197431,
#  509.22121739126385,
#  512.0835123970198,
#  514.0869353493248,
#  514.2572756975665,
#  514.2934666130182,
#  514.7198323871529,
#  514.8958434097034,
#  516.0272378804533,
#  517.5830296568431,
#  522.5891394239414,
#  522.6700763955462,
#  522.7179277616714,
#  522.7652536027394,
#  523.3771064589561,
#  523.6965982403552,
#  524.1421505421447,
#  524.6254650465689,
#  524.9047653708101,
#  526.9366094800814,
#  527.7837897574573,
#  530.7825795502289,
#  534.2136040631029,
#  534.6524820697803,
#  535.375950249366,
#  535.7058261303688,
#  536.0164400429787,
#  536.2901775427263,
#  537.3072387025538,
#  537.8236160300445,
#  538.2871860296594,
#  538.4276184500994,
#  538.8816559446485,
#  540.2501753455668,
#  542.3726738180237,
#  542.7952779159152,
#  543.3175823789123,
#  545.9680119103382,
#  547.4555234746936,
#  548.4664302457235,
#  548.5185292758069,
#  549.2589012492725,
#  549.8348482135557,
#  551.2716156432131,
#  553.3989264268793,
#  555.1247347033336,
#  555.6523233966551,
#  555.8925953881737,
#  557.5098251600402,
#  558.4039308643307,
#  562.0820453929382,
#  562.3709150010627,
#  565.3195732573001,
#  569.017358345486,
#  570.6300980875259,
#  573.0714500882775,
#  581.2377139084758,
#  593.0382935680913,
#  601.8168878409057,
#  616.6602860166827,
#  633.1326056725161]

# %% [markdown]
# * 아바타로 딱히 얻을 수 있는 것 업다 -> 삭제

# %%
data['Address']
# Out:
# 0           835 Frank Tunnel\nWrightmouth, MI 82180-9605
# 1         4547 Archer Common\nDiazchester, CA 06566-8576
# 2      24645 Valerie Unions Suite 582\nCobbborough, D...
# 3       1414 David Throughway\nPort Jason, OH 22070-1220
# 4      14023 Rodriguez Passage\nPort Jacobville, PR 3...
#                              ...
# 495    4483 Jones Motorway Suite 872\nLake Jamiefurt,...
# 496    172 Owen Divide Suite 497\nWest Richard, CA 19320
# 497    0787 Andrews Ranch Apt. 633\nSouth Chadburgh, ...
# 498    680 Jennifer Lodge Apt. 808\nBrendachester, TX...
# 499    49791 Rachel Heights Apt. 898\nEast Drewboroug...
# Name: Address, Length: 500, dtype: object

# %% [markdown]
# 주소 뒷부분만 뽑아보면 공통부분이 있을까? 확인해보기

# %%
data['Address'].str.split(",")
# Out:
# 0        [835 Frank Tunnel\nWrightmouth,  MI 82180-9605]
# 1      [4547 Archer Common\nDiazchester,  CA 06566-8576]
# 2      [24645 Valerie Unions Suite 582\nCobbborough, ...
# 3      [1414 David Throughway\nPort Jason,  OH 22070-...
# 4      [14023 Rodriguez Passage\nPort Jacobville,  PR...
#                              ...
# 495    [4483 Jones Motorway Suite 872\nLake Jamiefurt...
# 496    [172 Owen Divide Suite 497\nWest Richard,  CA ...
# 497    [0787 Andrews Ranch Apt. 633\nSouth Chadburgh,...
# 498    [680 Jennifer Lodge Apt. 808\nBrendachester,  ...
# 499    [49791 Rachel Heights Apt. 898\nEast Drewborou...
# Name: Address, Length: 500, dtype: object

# %%
for i in data['Address'].str.split(","):
    print(i[-1].split()[-2])
# Out:
# MI
# CA
# DC
# OH
# PR
# MN
# WV
# AP
# SD
# AA
# WY
# AA
# MO
# MP
# ND
# OH
# GA
# PW
# PW
# MT
# KY
# AE
# AA
# AA
# WV
# ND
# VI
# TX
# MS
# SC
# WA
# DC
# AA
# NJ
# MS
# NH
# PW
# MI
# ME
# ID
# TN
# AK
# KY
# DE
# AE
# FM
# HI
# KS
# NC
# TN
# UT
# MS
# CA
# AL
# AA
# LA
# NE
# OR
# SD
# AA
# MN
# CT
# WA
# MA
# DE
# IN
# MS
# AZ
# AE
# MH
# NC
# AP
# HI
# NY
# MH
# CO
# CO
# AE
# IN
# IA
# GU
# IN
# IA
# AP
# NC
# WV
# TX
# AK
# VI
# AL
# AS
# AE
# RI
# SD
# VA
# NC
# DE
# AE
# AP
# MD
# FM
# WV
# OK
# WI
# VT
# FL
# IL
# MH
# MO
# MP
# NV
# TX
# PA
# NC
# AL
# MS
# ME
# MP
# ND
# AA
# VA
# DC
# OH
# KY
# IL
# KY
# SC
# AS
# AE
# AS
# WI
# OH
# NJ
# CO
# OR
# AP
# MT
# NM
# DE
# VT
# SC
# SC
# IN
# OR
# DC
# HI
# MA
# PA
# MI
# CO
# NM
# DE
# MH
# SC
# UT
# WY
# MP
# AP
# VI
# NJ
# AE
# VI
# PA
# AA
# AP
# MH
# ND
# PA
# MT
# MO
# SD
# KY
# WI
# NV
# PR
# PA
# OR
# DE
# TX
# AK
# AR
# OR
# FL
# ME
# NC
# VT
# CA
# PR
# FL
# RI
# NJ
# IN
# RI
# NC
# SD
# SC
# NH
# VT
# PR
# WY
# FM
# WA
# WI
# WV
# AK
# NY
# AE
# AL
# PW
# MI
# LA
# FM
# SD
# AR
# NH
# VT
# IL
# HI
# KS
# ND
# DC
# RI
# IL
# MN
# VA
# AE
# GA
# PW
# OK
# NJ
# MD
# SC
# OR
# NM
# AL
# HI
# MI
# DE
# AE
# NE
# PW
# GU
# AZ
# FM
# AR
# ID
# MI
# VA
# WY
# AA
# IA
# LA
# VT
# NV
# WV
# AA
# VA
# OR
# KS
# NY
# RI
# KS
# WV
# FL
# NY
# AR
# MT
# RI
# WY
# KY
# FM
# AZ
# LA
# NM
# NH
# VT
# AS
# MN
# MO
# RI
# MD
# IN
# PA
# TX
# MT
# OR
# OK
# NV
# AP
# AP
# AZ
# MS
# SC
# TX
# ND
# CO
# SC
# AL
# MS
# NE
# OK
# AE
# AP
# PR
# FL
# IN
# GU
# MN
# MA
# IA
# AE
# GA
# OK
# WI
# IL
# MS
# AL
# WY
# PR
# MN
# LA
# NV
# PA
# AL
# GA
# HI
# SC
# DC
# NC
# NY
# VT
# WY
# MD
# NH
# GA
# SD
# NJ
# MH
# AK
# KS
# NH
# FL
# MT
# VT
# WA
# NH
# HI
# IA
# UT
# ND
# ND
# PR
# MA
# MT
# DE
# MA
# FL
# VT
# MA
# ME
# ID
# MN
# FM
# AK
# HI
# NE
# MI
# DE
# VT
# GA
# AR
# AA
# MS
# KS
# MO
# MH
# FL
# MN
# AL
# MI
# TN
# MI
# DE
# MN
# AZ
# ME
# MO
# NJ
# AS
# MO
# OR
# MP
# DE
# NM
# OH
# IL
# NM
# AR
# PA
# NJ
# AS
# AZ
# SC
# NY
# AS
# ME
# DC
# AK
# AP
# AZ
# AE
# TN
# CT
# OR
# VI
# NC
# HI
# DE
# FL
# MO
# NE
# UT
# DE
# MN
# AZ
# MD
# FL
# IL
# ND
# MO
# MT
# NJ
# NE
# IL
# GU
# CT
# NJ
# KY
# AE
# AA
# KS
# SC
# AA
# TX
# WV
# AE
# OK
# MO
# NV
# NY
# FM
# KS
# ME
# OR
# AA
# WV
# GA
# KS
# KS
# GU
# NC
# CT
# MO
# NY
# MS
# ME
# AE
# VT
# AA
# AA
# FL
# CA
# AE
# LA
# AS
# AS
# ME
# MA
# MS
# KY
# CA
# KS
# CT
# OK
# AZ
# MO
# IA
# IA
# SC
# GU
# GA
# MN
# VA
# MO
# VI
# UT
# CA
# TN
# TX
# OR

# %%
data['state_name'] =data['Address'].str.split(",").apply(lambda x: x[-1].split()[-2])
#i[-1].split()[-2] =>시리즈 -> applu로 하나씩 꺼내기 -> 람다로 할당

# %%
data
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# 495  4483 Jones Motorway Suite 872\nLake Jamiefurt,...               Tan
# 496  172 Owen Divide Suite 497\nWest Richard, CA 19320     PaleVioletRed
# 497  0787 Andrews Ranch Apt. 633\nSouth Chadburgh, ...          Cornsilk
# 498  680 Jennifer Lodge Apt. 808\nBrendachester, TX...              Teal
# 499  49791 Rachel Heights Apt. 898\nEast Drewboroug...       DarkMagenta
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
#      Yearly Amount Spent state_name
# 0             587.951054         MI
# 1             392.204933         CA
# 2             487.547505         DC
# 3             581.852344         OH
# 4             599.406092         PR
# ..                   ...        ...
# 495           573.847438         UT
# 496           529.049004         CA
# 497           551.620145         TN
# 498           456.469510         TX
# 499           497.778642         OR
#
# [500 rows x 9 columns]

# %%
data.groupby('state_name')['Yearly Amount Spent'].describe().sort_values(by='mean')
# Out:
#             count        mean         std         min         25%         50%  \
# state_name
# PW            6.0  413.315738   41.089085  347.776927  400.548738  409.858739
# GU            6.0  414.701360  100.849577  304.135592  342.417144  397.705547
# NH            7.0  448.609303   68.641665  352.550108  402.141196  461.790959
# NV            6.0  452.483974   84.186395  298.762008  439.175327  468.934705
# LA            6.0  461.629503   77.256200  368.654785  406.529416  464.109429
# ...           ...         ...         ...         ...         ...         ...
# MN           11.0  546.266279   81.288184  401.033135  485.806863  583.977802
# AR            6.0  550.633210   28.390539  517.165136  527.858082  553.068623
# IN            7.0  558.303399  122.284826  462.897636  470.345119  488.786061
# MP            5.0  560.966458   36.412356  503.175085  549.008227  573.415867
# UT            5.0  566.491138  119.244259  392.810345  544.409272  573.847438
#
#                    75%         max
# state_name
# PW          442.239989  461.920877
# GU          469.328461  571.471034
# NH          499.879045  521.883573
# NV          497.186987  542.412477
# LA          493.333888  582.491924
# ...                ...         ...
# MN          610.497563  637.102448
# AR          565.213072  591.781089
# IN          625.115698  765.518462
# MP          586.155870  593.077241
# UT          595.803819  725.584814
#
# [62 rows x 8 columns]

# %%
data.groupby('state_name')['Yearly Amount Spent'].describe().sort_values(by='min')
# Out:
#             count        mean         std         min         25%         50%  \
# state_name
# AE           18.0  482.601682   92.842442  256.670582  420.285739  474.498979
# PR            7.0  503.804542  112.601221  266.086341  499.286589  537.215053
# NC           10.0  486.433245   99.478551  275.918421  428.061720  506.623442
# NE            6.0  514.528367  129.523960  282.471246  495.434989  529.836864
# NV            6.0  452.483974   84.186395  298.762008  439.175327  468.934705
# ...           ...         ...         ...         ...         ...         ...
# OH            5.0  537.757418   49.818879  461.780742  514.239521  557.608262
# IN            7.0  558.303399  122.284826  462.897636  470.345119  488.786061
# MT            8.0  532.454993   45.631615  463.591418  501.423151  541.616592
# MP            5.0  560.966458   36.412356  503.175085  549.008227  573.415867
# AR            6.0  550.633210   28.390539  517.165136  527.858082  553.068623
#
#                    75%         max
# state_name
# AE          547.405206  614.715334
# PR          562.675565  599.406092
# NC          545.294161  618.845970
# NE          580.399596  663.803693
# NV          497.186987  542.412477
# ...                ...         ...
# OH          573.306222  581.852344
# IN          625.115698  765.518462
# MT          556.876805  605.061039
# MP          586.155870  593.077241
# AR          565.213072  591.781089
#
# [62 rows x 8 columns]

# %% [markdown]
# 선형성, 독립성, 등분산성, 정규성

# %% [markdown]
# 독립성-> 변수간 상관관계 있는지 확인하기

# %%
data.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent',
#        'state_name'],
#       dtype='object')

# %%
# data.corr() 
# 그냥 돌리면 에러나 numeric_only라는 조건 넣어주기 (숫자형만 뽑아서 상관분석 하는 것)

# %%
data.corr(numeric_only=True)
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.027826        -0.034987
# Time on App                     -0.027826     1.000000         0.082388
# Time on Website                 -0.034987     0.082388         1.000000
# Length of Membership             0.060247     0.029143        -0.047582
# Yearly Amount Spent              0.355088     0.499328        -0.002641
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length               0.060247             0.355088
# Time on App                       0.029143             0.499328
# Time on Website                  -0.047582            -0.002641
# Length of Membership              1.000000             0.809084
# Yearly Amount Spent               0.809084             1.000000

# %%
sns.heatmap(data.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
data= data.drop(['Email', 'Address', 'Avatar'], axis=1)
data.head()
# Out:
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent state_name
# 0           587.951054         MI
# 1           392.204933         CA
# 2           487.547505         DC
# 3           581.852344         OH
# 4           599.406092         PR

# %% [markdown]
# 컬럼명에 공백 들어가 있으면 오류날 가능성 높다 -> 공백없애주기

# %%
data.columns #리스트 형태
# Out:
# Index(['Avg. Session Length', 'Time on App', 'Time on Website',
#        'Length of Membership', 'Yearly Amount Spent', 'state_name'],
#       dtype='object')

# %%
data.columns=[col.replace(" ","").replace(".","") for col in data.columns]
data.head()
# Out:
#    AvgSessionLength  TimeonApp  TimeonWebsite  LengthofMembership  \
# 0         34.497268  12.655651      39.577668            4.082621
# 1         31.926272  11.109461      37.268959            2.664034
# 2         33.000915  11.330278      37.110597            4.104543
# 3         34.305557  13.717514      36.721283            3.120179
# 4         33.330673  12.795189      37.536653            4.446308
#
#    YearlyAmountSpent state_name
# 0         587.951054         MI
# 1         392.204933         CA
# 2         487.547505         DC
# 3         581.852344         OH
# 4         599.406092         PR

# %%
X= data.drop('YearlyAmountSpent', axis=1)
y= data['YearlyAmountSpent']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, =0.2, random_state=7)

# %% [markdown]
# 다중선형회귀분석

# %%
# statsmodels R 문법
from statsmodels.formula.api import ols

# %%
train_data = pd.concat([X_train, y_train],axis=1)
train_data.head()

# %%
train_data.columns

# %%
lm=ols('')

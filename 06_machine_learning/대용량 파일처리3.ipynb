# %%
# import pandas as pd
# data= pd.read_csv("C:/fintech_service/06_machine_learning/data/final_fliter_data2.csv")
# data
# Out:
#                          시군구            단지명   전용면적(㎡) 거래금액(만원)   층    건축년도  \
# 0         강원특별자치도 양구군 양구읍 상리             경림   59.4000    5,000  11  1998.0
# 1               경기도 의정부시 신곡동            신일1   59.8780    5,750   3  1997.0
# 2               경기도 의정부시 신곡동             풍림   49.8300    5,500   8  1998.0
# 3               경기도 의정부시 민락동          한라비발디   84.9900   12,750  19  2003.0
# 4               경기도 의정부시 용현동         용현현대1차  129.7300   12,200  11  1992.0
# ...                      ...            ...       ...      ...  ..     ...
# 10041446    충청남도 서산시 대산읍 대산리             한미   58.4700    3,000   5  1992.0
# 10041447        경상북도 안동시 법흥동    안동강변펠리시아아파트  116.4457   52,000   7  2017.0
# 10041448        경상북도 구미시 오태동  신한디아체101동102동   59.9800    4,700   1  1999.0
# 10041449     경상남도 양산시 동면 석산리     양산이지더원리버포레   78.2990   34,200  15  2017.0
# 10041450     전북특별자치도 남원시 월락동       양우내안애아파트   59.9896   20,900  15  2016.0
#
#                 date     달러환율  기준금리           분류
# ...

# %%
import pandas as pd
learning_place = pd.read_csv("C:/fintech_service/06_machine_learning/data/학원교습소정보_2024년08월31일기준.csv", encoding='cp949')
learning_place
# Out:
# C:\Users\5-06\AppData\Local\Temp\ipykernel_12348\1175705376.py:2: DtypeWarning: Columns (6,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   learning_place = pd.read_csv("C:/fintech_service/06_machine_learning/data/학원교습소정보_2024년08월31일기준.csv", encoding='cp949')
#        시도교육청코드      시도교육청명 행정구역명 학원교습소구분명      학원지정번호                     학원명  \
# 0          B10    서울특별시교육청   강남구       학원  3000040160                    대치학원
# 1          B10    서울특별시교육청   강남구       학원  3000039285      (A STUDIO)에이스튜디오학원
# 2          B10    서울특별시교육청   강남구       학원        2531            (주)멘토르수학전문학원
# 3          B10    서울특별시교육청   강남구       학원  3000012704     (주)산에듀김영준국어논술전문별관학원
# 4          B10    서울특별시교육청   강남구       학원  3000043003  (주)산에듀김영준국어논술전문프리미엄관학원
# ...        ...         ...   ...      ...         ...                     ...
# 136611     T10  제주특별자치도교육청   제주시      교습소        3699              화가처럼그리기교습소
# ...

# %%
learning_place.isna().sum()
# Out:
# 시도교육청코드           0
# 시도교육청명            0
# 행정구역명           142
# 학원교습소구분명          0
# 학원지정번호            0
# 학원명               0
# 개설일자              0
# 등록일자              0
# 등록상태명             0
# 휴원시작일자            0
# 휴원종료일자            0
# 정원합계              0
# 일시수용능력인원합계        0
# 분야명               4
# 교습계열명         17050
# 교습과정목록명       37580
# 교습과정명         17025
# 인당수강료내용           0
# 수강료공개여부           0
# 기숙사학원여부           0
# 시설도로명주소           0
# 시설도로명상세주소         0
# 시설도로명우편번호         0
# 전화번호          54542
# 수정일자              0
# dtype: int64

# %%
learn_place=learning_place[['시도교육청명', '행정구역명']]
learn_place
# Out:
#             시도교육청명 행정구역명
# 0         서울특별시교육청   강남구
# 1         서울특별시교육청   강남구
# 2         서울특별시교육청   강남구
# 3         서울특별시교육청   강남구
# 4         서울특별시교육청   강남구
# ...            ...   ...
# 136611  제주특별자치도교육청   제주시
# 136612  제주특별자치도교육청   제주시
# 136613  제주특별자치도교육청   제주시
# 136614  제주특별자치도교육청   제주시
# 136615  제주특별자치도교육청   제주시
#
# [136616 rows x 2 columns]

# %%
learn_place.isna().sum()
# Out:
# 시도교육청명      0
# 행정구역명     142
# dtype: int64

# %%
# '시도교육청' 컬럼에서 '전라북도교육청'을 '전북특별자치도교육청'으로 변경
learn_place['시도교육청명'] = learn_place['시도교육청명'].replace('전라북도교육청', '전북특별자치도교육청')

# 변경된 값 확인
learn_place['시도교육청명'].unique()
# Out:
# C:\Users\5-06\AppData\Local\Temp\ipykernel_12348\1460280585.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   learn_place['시도교육청명'] = learn_place['시도교육청명'].replace('전라북도교육청', '전북특별자치도교육청')
# array(['서울특별시교육청', '부산광역시교육청', '대구광역시교육청', '인천광역시교육청', '광주광역시교육청',
#        '대전광역시교육청', '울산광역시교육청', '세종특별자치시교육청', '경기도교육청', '강원특별자치도교육청',
#        '충청북도교육청', '충청남도교육청', '전북특별자치도교육청', '전라남도교육청', '경상북도교육청',
#        '경상남도교육청', '제주특별자치도교육청'], dtype=object)

# %%
# '시도교육청' 값의 오른쪽에서 세 글자 제거
learn_place['시도교육청명'] = learn_place['시도교육청명'].str[:-3]
learn_place
# '시도교육청'과 '행정구역명' 데이터를 합쳐서 '시군구' 컬럼 생성
learn_place['시군구'] = learn_place['시도교육청명'] + ' ' + learn_place['행정구역명']
learn_place
# Out:
# C:\Users\5-06\AppData\Local\Temp\ipykernel_12348\439447029.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   learn_place['시도교육청명'] = learn_place['시도교육청명'].str[:-3]
# C:\Users\5-06\AppData\Local\Temp\ipykernel_12348\439447029.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   learn_place['시군구'] = learn_place['시도교육청명'] + ' ' + learn_place['행정구역명']
#          시도교육청명 행정구역명          시군구
# 0         서울특별시   강남구    서울특별시 강남구
# 1         서울특별시   강남구    서울특별시 강남구
# ...

# %% [markdown]
#  '세종특별자치시 세종특별자치시','경상남도 창원시(폐지)' -처리해주기

# %%
# '시도교육청' 컬럼에서 '전라북도교육청'을 '전북특별자치도교육청'으로 변경
learn_place['시군구'] = learn_place['시군구'].replace( '세종특별자치시 세종특별자치시', '세종특별자치시')
learn_place['시군구'] = learn_place['시군구'].replace( '경상남도 창원시(폐지)', '경상남도 창원시')
# Out:
# C:\Users\5-06\AppData\Local\Temp\ipykernel_12348\1379825619.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   learn_place['시군구'] = learn_place['시군구'].replace( '세종특별자치시 세종특별자치시', '세종특별자치시')
# C:\Users\5-06\AppData\Local\Temp\ipykernel_12348\1379825619.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   learn_place['시군구'] = learn_place['시군구'].replace( '경상남도 창원시(폐지)', '경상남도 창원시')

# %%
learn_place.isna().sum()
# Out:
# 시도교육청명      0
# 행정구역명     142
# 시군구       142
# dtype: int64

# %%
# 결측값을 가진 행만 선택하는 코드
miss=learn_place[learn_place.isnull().any(axis=1)]
miss
# Out:
#        시도교육청명 행정구역명  시군구
# 26061   서울특별시   NaN  NaN
# 26062   서울특별시   NaN  NaN
# 26063   서울특별시   NaN  NaN
# 26064   서울특별시   NaN  NaN
# 26065   서울특별시   NaN  NaN
# ...       ...   ...  ...
# 107667   충청북도   NaN  NaN
# 112005   충청남도   NaN  NaN
# 126180   경상북도   NaN  NaN
# 134882   경상남도   NaN  NaN
# 134883   경상남도   NaN  NaN
#
# [142 rows x 3 columns]

# %%
miss['시도교육청명'].unique()
# Out:
# array(['서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '울산광역시', '경기도',
#        '강원특별자치도', '충청북도', '충청남도', '경상북도', '경상남도'], dtype=object)

# %%
learn_place['시군구'].unique()
# Out:
# array(['서울특별시 강남구', '서울특별시 강동구', '서울특별시 강북구', '서울특별시 강서구', '서울특별시 관악구',
#        '서울특별시 광진구', '서울특별시 구로구', '서울특별시 금천구', '서울특별시 노원구', '서울특별시 도봉구',
#        '서울특별시 동대문구', '서울특별시 동작구', '서울특별시 마포구', '서울특별시 서대문구', '서울특별시 서초구',
#        '서울특별시 성동구', '서울특별시 성북구', '서울특별시 송파구', '서울특별시 양천구', '서울특별시 영등포구',
#        '서울특별시 용산구', '서울특별시 은평구', '서울특별시 종로구', '서울특별시 중구', '서울특별시 중랑구',
#        nan, '부산광역시 강서구', '부산광역시 금정구', '부산광역시 기장군', '부산광역시 남구', '부산광역시 동구',
#        '부산광역시 동래구', '부산광역시 부산진구', '부산광역시 북구', '부산광역시 사상구', '부산광역시 사하구',
#        '부산광역시 서구', '부산광역시 수영구', '부산광역시 연제구', '부산광역시 영도구', '부산광역시 중구',
#        '부산광역시 해운대구', '대구광역시 군위군', '대구광역시 남구', '대구광역시 달서구', '대구광역시 달성군',
#        '대구광역시 동구', '대구광역시 북구', '대구광역시 서구', '대구광역시 수성구', '대구광역시 중구',
#        '인천광역시 강화군', '인천광역시 계양구', '인천광역시 남동구', '인천광역시 동구', '인천광역시 미추홀구',
#        '인천광역시 부평구', '인천광역시 서구', '인천광역시 연수구', '인천광역시 옹진군', '인천광역시 중구',
#        '광주광역시 광산구', '광주광역시 남구', '광주광역시 동구', '광주광역시 북구', '광주광역시 서구',
# ...

# %%
# '시군구' 컬럼의 값별로 개수 세기
count_per_sigungu = learn_place['시군구'].value_counts().reset_index()

# 데이터프레임의 컬럼명 변경
count_per_sigungu.columns = ['시군구', '학원수']

count_per_sigungu
# Out:
#            시군구   학원수
# 0    서울특별시 강남구  3678
# 1      경기도 수원시  3570
# 2      경기도 고양시  3485
# 3      경기도 용인시  3328
# 4      경기도 성남시  3225
# ..         ...   ...
# 230   경상북도 청송군     9
# 231   전라남도 신안군     6
# 232   충청북도 청주시     5
# 233  인천광역시 옹진군     5
# 234   경상북도 울릉군     4
#
# [235 rows x 2 columns]

# %%
count_per_sigungu.isna().sum()
# Out:
# 시군구    0
# 학원수    0
# dtype: int64

# %%
count_per_sigungu['시군구'].unique()
# Out:
# array(['서울특별시 강남구', '경기도 수원시', '경기도 고양시', '경기도 용인시', '경기도 성남시', '경기도 화성시',
#        '경상남도 창원시', '전북특별자치도 전주시', '대구광역시 수성구', '서울특별시 양천구', '경기도 부천시',
#        '서울특별시 송파구', '경기도 남양주시', '서울특별시 서초구', '대구광역시 달서구', '경기도 안양시',
#        '충청남도 천안시', '경기도 김포시', '인천광역시 서구', '경상남도 김해시', '세종특별자치시',
#        '대전광역시 서구', '서울특별시 노원구', '부산광역시 해운대구', '서울특별시 강서구', '울산광역시 남구',
#        '경기도 시흥시', '경상북도 포항시', '서울특별시 강동구', '제주특별자치도 제주시', '인천광역시 연수구',
#        '광주광역시 북구', '경상북도 구미시', '경기도 평택시', '광주광역시 광산구', '경상남도 진주시',
#        '경기도 안산시', '대구광역시 북구', '서울특별시 마포구', '경기도 파주시', '경기도 의정부시',
#        '인천광역시 남동구', '서울특별시 은평구', '대전광역시 유성구', '부산광역시 동래구', '경기도 하남시',
#        '서울특별시 성북구', '서울특별시 동작구', '강원특별자치도 원주시', '인천광역시 부평구', '경상남도 양산시',
#        '광주광역시 서구', '광주광역시 남구', '대구광역시 동구', '부산광역시 부산진구', '경기도 광명시',
#        '서울특별시 영등포구', '경기도 광주시', '서울특별시 구로구', '서울특별시 관악구', '서울특별시 광진구',
#        '서울특별시 서대문구', '경기도 군포시', '대구광역시 달성군', '전라남도 순천시', '충청북도 흥덕구',
# ...

# %%
# count_per_sigungu.to_csv("C:/fintech_service/06_machine_learning/data/learn_place_count_data.csv", index=False)

# %%
count_per_sigungu['학원수'].unique()
# Out:
# array([3678, 3570, 3485, 3328, 3225, 3112, 2951, 2669, 2464, 2126, 2064,
#        2024, 2006, 1936, 1798, 1764, 1754, 1632, 1595, 1573, 1569, 1451,
#        1448, 1427, 1385, 1362, 1358, 1349, 1345, 1300, 1292, 1288, 1275,
#        1259, 1251, 1242, 1218, 1189, 1166, 1158, 1151, 1147, 1122, 1093,
#        1076,  972,  964,  961,  951,  949,  928,  896,  894,  890,  862,
#         856,  785,  781,  767,  746,  745,  738,  728,  724,  715,  696,
#         692,  688,  674,  666,  657,  656,  632,  631,  629,  626,  610,
#         604,  595,  592,  589,  579,  578,  574,  571,  569,  567,  539,
#         531,  523,  518,  515,  506,  501,  497,  478,  469,  432,  424,
#         420,  390,  388,  385,  380,  374,  363,  348,  335,  332,  330,
#         317,  308,  303,  287,  283,  279,  266,  265,  263,  260,  258,
#         255,  254,  246,  228,  223,  220,  215,  206,  192,  181,  173,
#         168,  159,  157,  149,  147,  143,  139,  137,  135,  124,  120,
# ...

# %%
# merged_final에 '분류' 데이터를 기준으로 count_per_sigungu의 '학원수' 데이터를 left join
merged_final = data.merge(count_per_sigungu[['시군구', '학원수']],
                                  left_on='분류', 
                                  right_on='시군구', 
                                  how='left')

merged_final
# Out:
#                        시군구_x            단지명   전용면적(㎡) 거래금액(만원)   층    건축년도  \
# 0         강원특별자치도 양구군 양구읍 상리             경림   59.4000    5,000  11  1998.0
# 1               경기도 의정부시 신곡동            신일1   59.8780    5,750   3  1997.0
# 2               경기도 의정부시 신곡동             풍림   49.8300    5,500   8  1998.0
# 3               경기도 의정부시 민락동          한라비발디   84.9900   12,750  19  2003.0
# 4               경기도 의정부시 용현동         용현현대1차  129.7300   12,200  11  1992.0
# ...                      ...            ...       ...      ...  ..     ...
# 10041446    충청남도 서산시 대산읍 대산리             한미   58.4700    3,000   5  1992.0
# 10041447        경상북도 안동시 법흥동    안동강변펠리시아아파트  116.4457   52,000   7  2017.0
# 10041448        경상북도 구미시 오태동  신한디아체101동102동   59.9800    4,700   1  1999.0
# 10041449     경상남도 양산시 동면 석산리     양산이지더원리버포레   78.2990   34,200  15  2017.0
# 10041450     전북특별자치도 남원시 월락동       양우내안애아파트   59.9896   20,900  15  2016.0
#
# ...

# %%
# '시군구_y' 컬럼 삭제
merged_final = merged_final.drop(columns=['시군구_y'])
merged_final
# Out:
#                        시군구_x            단지명   전용면적(㎡) 거래금액(만원)   층    건축년도  \
# 0         강원특별자치도 양구군 양구읍 상리             경림   59.4000    5,000  11  1998.0
# 1               경기도 의정부시 신곡동            신일1   59.8780    5,750   3  1997.0
# 2               경기도 의정부시 신곡동             풍림   49.8300    5,500   8  1998.0
# 3               경기도 의정부시 민락동          한라비발디   84.9900   12,750  19  2003.0
# 4               경기도 의정부시 용현동         용현현대1차  129.7300   12,200  11  1992.0
# ...                      ...            ...       ...      ...  ..     ...
# 10041446    충청남도 서산시 대산읍 대산리             한미   58.4700    3,000   5  1992.0
# 10041447        경상북도 안동시 법흥동    안동강변펠리시아아파트  116.4457   52,000   7  2017.0
# 10041448        경상북도 구미시 오태동  신한디아체101동102동   59.9800    4,700   1  1999.0
# 10041449     경상남도 양산시 동면 석산리     양산이지더원리버포레   78.2990   34,200  15  2017.0
# 10041450     전북특별자치도 남원시 월락동       양우내안애아파트   59.9896   20,900  15  2016.0
#
#                 date     달러환율  기준금리           분류     학원수
# ...

# %%
merged_final = merged_final.drop(columns=['분류'])
merged_final
# Out:
#                        시군구_x            단지명   전용면적(㎡) 거래금액(만원)   층    건축년도  \
# 0         강원특별자치도 양구군 양구읍 상리             경림   59.4000    5,000  11  1998.0
# 1               경기도 의정부시 신곡동            신일1   59.8780    5,750   3  1997.0
# 2               경기도 의정부시 신곡동             풍림   49.8300    5,500   8  1998.0
# 3               경기도 의정부시 민락동          한라비발디   84.9900   12,750  19  2003.0
# 4               경기도 의정부시 용현동         용현현대1차  129.7300   12,200  11  1992.0
# ...                      ...            ...       ...      ...  ..     ...
# 10041446    충청남도 서산시 대산읍 대산리             한미   58.4700    3,000   5  1992.0
# 10041447        경상북도 안동시 법흥동    안동강변펠리시아아파트  116.4457   52,000   7  2017.0
# 10041448        경상북도 구미시 오태동  신한디아체101동102동   59.9800    4,700   1  1999.0
# 10041449     경상남도 양산시 동면 석산리     양산이지더원리버포레   78.2990   34,200  15  2017.0
# 10041450     전북특별자치도 남원시 월락동       양우내안애아파트   59.9896   20,900  15  2016.0
#
#                 date     달러환율  기준금리     학원수
# ...

# %%
# '시군구_x' 컬럼명을 '시군구'로 변경
merged_final = merged_final.rename(columns={'시군구_x': '시군구'})

merged_final
# Out:
#                          시군구            단지명   전용면적(㎡) 거래금액(만원)   층    건축년도  \
# 0         강원특별자치도 양구군 양구읍 상리             경림   59.4000    5,000  11  1998.0
# 1               경기도 의정부시 신곡동            신일1   59.8780    5,750   3  1997.0
# 2               경기도 의정부시 신곡동             풍림   49.8300    5,500   8  1998.0
# 3               경기도 의정부시 민락동          한라비발디   84.9900   12,750  19  2003.0
# 4               경기도 의정부시 용현동         용현현대1차  129.7300   12,200  11  1992.0
# ...                      ...            ...       ...      ...  ..     ...
# 10041446    충청남도 서산시 대산읍 대산리             한미   58.4700    3,000   5  1992.0
# 10041447        경상북도 안동시 법흥동    안동강변펠리시아아파트  116.4457   52,000   7  2017.0
# 10041448        경상북도 구미시 오태동  신한디아체101동102동   59.9800    4,700   1  1999.0
# 10041449     경상남도 양산시 동면 석산리     양산이지더원리버포레   78.2990   34,200  15  2017.0
# 10041450     전북특별자치도 남원시 월락동       양우내안애아파트   59.9896   20,900  15  2016.0
#
#                 date     달러환율  기준금리     학원수
# ...

# %%
# 칼럼 순서를 지정
new_column_order = ['시군구', '단지명', '전용면적(㎡)', '거래금액(만원)', '층', '건축년도', '학원수', 'date', '기준금리', '달러환율']

# 지정한 순서대로 데이터프레임의 컬럼 재배치
merged_final= merged_final[new_column_order]
merged_final
# Out:
#                          시군구            단지명   전용면적(㎡) 거래금액(만원)   층    건축년도  \
# 0         강원특별자치도 양구군 양구읍 상리             경림   59.4000    5,000  11  1998.0
# 1               경기도 의정부시 신곡동            신일1   59.8780    5,750   3  1997.0
# 2               경기도 의정부시 신곡동             풍림   49.8300    5,500   8  1998.0
# 3               경기도 의정부시 민락동          한라비발디   84.9900   12,750  19  2003.0
# 4               경기도 의정부시 용현동         용현현대1차  129.7300   12,200  11  1992.0
# ...                      ...            ...       ...      ...  ..     ...
# 10041446    충청남도 서산시 대산읍 대산리             한미   58.4700    3,000   5  1992.0
# 10041447        경상북도 안동시 법흥동    안동강변펠리시아아파트  116.4457   52,000   7  2017.0
# 10041448        경상북도 구미시 오태동  신한디아체101동102동   59.9800    4,700   1  1999.0
# 10041449     경상남도 양산시 동면 석산리     양산이지더원리버포레   78.2990   34,200  15  2017.0
# 10041450     전북특별자치도 남원시 월락동       양우내안애아파트   59.9896   20,900  15  2016.0
#
#              학원수        date  기준금리     달러환율
# ...

# %%
# 필요한 경우 병합된 데이터를 저장
merged_final.to_csv("C:/fintech_service/06_machine_learning/data/final_dataset.csv", index=False)

# %%
merged_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10041451 entries, 0 to 10041450
# Data columns (total 10 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   시군구       object
#  1   단지명       object
#  2   전용면적(㎡)   float64
#  3   거래금액(만원)  object
#  4   층         int64
#  5   건축년도      float64
#  6   학원수       float64
#  7   date      object
#  8   기준금리      float64
#  9   달러환율      float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 766.1+ MB

# %%
merged_final.isna().sum()
# Out:
# 시군구               0
# 단지명               0
# 전용면적(㎡)           0
# 거래금액(만원)          0
# 층                 0
# 건축년도              0
# 학원수         2007352
# date              0
# 기준금리              0
# 달러환율              0
# dtype: int64

# %%
# '학원수' 컬럼에서 NaN 값을 가진 행들을 확인
nan_rows = merged_final[merged_final['학원수'].isna()]

# NaN이 있는지 확인
nan_rows
# Out:
#                      시군구                  단지명  전용면적(㎡) 거래금액(만원)   층    건축년도  \
# 6         경상남도 창원성산구 남양동                 피오르빌  39.7000    4,300  14  1995.0
# 7         경상남도 창원성산구 남양동                 피오르빌  49.5100    6,950   9  1995.0
# 8         경상남도 창원성산구 남양동                 피오르빌  49.5100    6,300  13  1995.0
# 9         경상남도 창원성산구 대방동                대동황토방  84.1272   24,900  12  2001.0
# 10        경상남도 창원성산구 대방동                 대방동성  60.0000   10,120  20  1996.0
# ...                  ...                  ...      ...      ...  ..     ...
# 10040207    세종특별자치시  도담동     도램마을1단지(웅진스타클래스)  59.9700   41,000  12  2014.0
# 10040224    세종특별자치시  고운동  가락마을6단지(중흥S클래스프라디움)  59.6866   38,700  23  2015.0
# 10040233    세종특별자치시  고운동      가락마을17단지(골드클래스)  59.9159   32,500  11  2015.0
# 10040240    세종특별자치시  고운동    가락마을9단지(신동아 파밀리에)  59.9718   31,500  15  2015.0
# 10040242    세종특별자치시  도담동       중흥 그린카운티(13단지)  59.1132   38,300  13  2014.0
#
#           학원수        date  기준금리     달러환율
# ...

# %%
nan_rows['시군구'].unique()
# Out:
# array(['경상남도 창원성산구 남양동', '경상남도 창원성산구 대방동', '경상남도 창원성산구 반림동',
#        '경상남도 창원성산구 상남동', '경상남도 창원성산구 안민동', '경상남도 창원의창구 도계동',
#        '경상남도 창원진해구 경화동', '경상남도 창원의창구 팔용동', '경상남도 창원진해구 용원동',
#        '경상남도 창원진해구 풍호동', '전라북도 전주덕진구 송천동1가', '경상남도 창원성산구 가음동',
#        '전라북도 전주덕진구 송천동2가', '경상남도 창원마산합포구 진동면 요장리', '경상남도 창원마산회원구 구암동',
#        '경상남도 창원마산회원구 내서읍 삼계리', '경상남도 창원마산회원구 내서읍 중리',
#        '경상남도 창원마산회원구 내서읍 호계리', '경상남도 창원마산회원구 석전동', '경상북도 포항남구 대잠동',
#        '경상북도 포항남구 연일읍 생지리', '경상북도 포항북구 득량동', '경상북도 포항북구 용흥동',
#        '경상북도 포항북구 창포동', '전라북도 전주완산구 효자동1가', '전라북도 전주완산구 중화산동2가',
#        '전라북도 전주완산구 효자동3가', '전라북도 전주덕진구 인후동1가', '전라북도 전주완산구 서신동',
#        '전라북도 전주완산구 중화산동1가', '충청남도 천안동남구 신방동', '경기도 수원팔달구 우만동',
#        '충청남도 천안동남구 청수동', '충청남도 천안동남구 원성동', '경기도 수원팔달구 인계동',
#        '경기도 수원팔달구 화서동', '경기도 수원팔달구 매산로2가', '경기도 안산단원구 초지동',
#        '경기도 안산상록구 건건동', '경기도 안산상록구 본오동', '경기도 안산상록구 사동', '경기도 안산상록구 성포동',
#        '경기도 안산단원구 신길동', '경기도 안산단원구 선부동', '충청남도 천안동남구 목천읍 신계리',
# ...

# %%
nan_rows['분류'] = nan_rows['시군구'].apply(lambda x: ' '.join(x.split()[:2]))
nan_rows['분류'].unique()
# Out:
# C:\Users\5-06\AppData\Local\Temp\ipykernel_5908\3094543104.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nan_rows['분류'] = nan_rows['시군구'].apply(lambda x: ' '.join(x.split()[:2]))
# array(['경상남도 창원성산구', '경상남도 창원의창구', '경상남도 창원진해구', '전라북도 전주덕진구',
#        '경상남도 창원마산합포구', '경상남도 창원마산회원구', '경상북도 포항남구', '경상북도 포항북구',
#        '전라북도 전주완산구', '충청남도 천안동남구', '경기도 수원팔달구', '경기도 안산단원구', '경기도 안산상록구',
#        '경기도 수원장안구', '경기도 수원권선구', '충청남도 천안서북구', '경기도 수원영통구', '경기도 성남중원구',
#        '경기도 용인기흥구', '경기도 용인수지구', '경기도 용인처인구', '경기도 안양동안구', '경기도 안양만안구',
#        '세종특별자치시 소정면', '세종특별자치시 연서면', '세종특별자치시 조치원읍', '경기도 성남분당구',
#        '경기도 고양일산동구', '경기도 고양일산서구', '충청북도 청주흥덕구', '충청북도 청주상당구',
#        '경기도 고양덕양구', '경기도 성남수정구', '충청북도 청주서원구', '충청북도 청주청원구',
# ...

# %%
경상남도 창원시
'경상남도 창원성산구', '경상남도 창원의창구', '경상남도 창원진해구', '경상남도 창원마산합포구', '경상남도 창원마산회원구'

# %%
전북특별자치도 전주시
'전라북도 전주덕진구','전라북도 전주완산구'

# %%
경상북도 포항시
'경상북도 포항남구', '경상북도 포항북구'

# %%
충청남도 천안시
'충청남도 천안동남구','충청남도 천안서북구'

# %%
경기도 수원시
'경기도 수원팔달구','경기도 수원장안구', '경기도 수원권선구','경기도 수원영통구'

# %%
경기도 안산시
'경기도 안산단원구', '경기도 안산상록구'

# %%
경기도 용인시
'경기도 용인기흥구', '경기도 용인수지구', '경기도 용인처인구'

# %%
경기도 성남시
'경기도 성남중원구','경기도 성남수정구'

# %%
경기도 안양시
'경기도 안양동안구', '경기도 안양만안구'

# %%
세종특별자치시
'세종특별자치시 소정면', '세종특별자치시 연서면', '세종특별자치시 조치원읍', '경기도 성남분당구', 
'세종특별자치시 금남면', '세종특별자치시 전동면', '세종특별자치시 부강면', '세종특별자치시 전의면',
'세종특별자치시 연동면', '세종특별자치시 한솔동', '세종특별자치시 어진동', '세종특별자치시 나성동',
'세종특별자치시 종촌동', '세종특별자치시 아름동', '세종특별자치시 장군면', '세종특별자치시 도담동',
'세종특별자치시 고운동', '세종특별자치시 소담동', '세종특별자치시 보람동', '세종특별자치시 새롬동',
'세종특별자치시 대평동', '세종특별자치시 다정동', '세종특별자치시 반곡동', '세종특별자치시 가람동',
'세종특별자치시 해밀동', '세종특별자치시 집현동', '세종특별자치시 산울동'

# %%
경기도 고양시
'경기도 고양일산동구', '경기도 고양일산서구','경기도 고양덕양구'

# %%
충청북도 청주시
'충청북도 청주흥덕구', '충청북도 청주상당구','충청북도 청주서원구', '충청북도 청주청원구'

# %%
import pandas as pd
final= pd.read_csv("C:/fintech_service/06_machine_learning/data/final_fliter_data2.csv", encoding='UTF8')
final
# Out:
#                          시군구            단지명   전용면적(㎡) 거래금액(만원)   층    건축년도  \
# 0         강원특별자치도 양구군 양구읍 상리             경림   59.4000    5,000  11  1998.0
# 1               경기도 의정부시 신곡동            신일1   59.8780    5,750   3  1997.0
# 2               경기도 의정부시 신곡동             풍림   49.8300    5,500   8  1998.0
# 3               경기도 의정부시 민락동          한라비발디   84.9900   12,750  19  2003.0
# 4               경기도 의정부시 용현동         용현현대1차  129.7300   12,200  11  1992.0
# ...                      ...            ...       ...      ...  ..     ...
# 10041446    충청남도 서산시 대산읍 대산리             한미   58.4700    3,000   5  1992.0
# 10041447        경상북도 안동시 법흥동    안동강변펠리시아아파트  116.4457   52,000   7  2017.0
# 10041448        경상북도 구미시 오태동  신한디아체101동102동   59.9800    4,700   1  1999.0
# 10041449     경상남도 양산시 동면 석산리     양산이지더원리버포레   78.2990   34,200  15  2017.0
# 10041450     전북특별자치도 남원시 월락동       양우내안애아파트   59.9896   20,900  15  2016.0
#
#                 date     달러환율  기준금리           분류
# ...

# %%
# '분류' 컬럼에서 포항의 각 구를 '경상북도 포항시'로 변경
final['분류'] = final['분류'].replace({
    '경상북도 포항남구': '경상북도 포항시',
    '경상북도 포항북구': '경상북도 포항시'
})

# %%
# '분류' 컬럼에서 세종특별자치시 각 지역을 '세종특별자치시'로 변경
final['분류'] = final['분류'].replace({
    '세종특별자치시 소정면': '세종특별자치시',
    '세종특별자치시 연서면': '세종특별자치시',
    '세종특별자치시 조치원읍': '세종특별자치시',
    '세종특별자치시 금남면': '세종특별자치시',
    '세종특별자치시 전동면': '세종특별자치시',
    '세종특별자치시 부강면': '세종특별자치시',
    '세종특별자치시 전의면': '세종특별자치시',
    '세종특별자치시 연동면': '세종특별자치시',
    '세종특별자치시 한솔동': '세종특별자치시',
    '세종특별자치시 어진동': '세종특별자치시',
    '세종특별자치시 나성동': '세종특별자치시',
    '세종특별자치시 종촌동': '세종특별자치시',
    '세종특별자치시 아름동': '세종특별자치시',
    '세종특별자치시 장군면': '세종특별자치시',
    '세종특별자치시 도담동': '세종특별자치시',
    '세종특별자치시 고운동': '세종특별자치시',
    '세종특별자치시 소담동': '세종특별자치시',
    '세종특별자치시 보람동': '세종특별자치시',
    '세종특별자치시 새롬동': '세종특별자치시',
    '세종특별자치시 대평동': '세종특별자치시',
    '세종특별자치시 다정동': '세종특별자치시',
    '세종특별자치시 반곡동': '세종특별자치시',
    '세종특별자치시 가람동': '세종특별자치시',
    '세종특별자치시 해밀동': '세종특별자치시',
    '세종특별자치시 집현동': '세종특별자치시',
    '세종특별자치시 산울동': '세종특별자치시',
})

# %%
final
# Out:
#                          시군구            단지명   전용면적(㎡) 거래금액(만원)   층    건축년도  \
# 0         강원특별자치도 양구군 양구읍 상리             경림   59.4000    5,000  11  1998.0
# 1               경기도 의정부시 신곡동            신일1   59.8780    5,750   3  1997.0
# 2               경기도 의정부시 신곡동             풍림   49.8300    5,500   8  1998.0
# 3               경기도 의정부시 민락동          한라비발디   84.9900   12,750  19  2003.0
# 4               경기도 의정부시 용현동         용현현대1차  129.7300   12,200  11  1992.0
# ...                      ...            ...       ...      ...  ..     ...
# 10041446    충청남도 서산시 대산읍 대산리             한미   58.4700    3,000   5  1992.0
# 10041447        경상북도 안동시 법흥동    안동강변펠리시아아파트  116.4457   52,000   7  2017.0
# 10041448        경상북도 구미시 오태동  신한디아체101동102동   59.9800    4,700   1  1999.0
# 10041449     경상남도 양산시 동면 석산리     양산이지더원리버포레   78.2990   34,200  15  2017.0
# 10041450     전북특별자치도 남원시 월락동       양우내안애아파트   59.9896   20,900  15  2016.0
#
#                 date     달러환율  기준금리           분류
# ...

# %%
# # 필요한 경우 병합된 데이터를 저장
# final.to_csv("C:/fintech_service/06_machine_learning/data/final_filter_apart_data.csv", index=False)

# %%
# !pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in c:\users\5-06\miniforge3\envs\openai\lib\site-packages (1.55.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\5-06\miniforge3\envs\openai\lib\site-packages (from openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\5-06\miniforge3\envs\openai\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\5-06\miniforge3\envs\openai\lib\site-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\5-06\miniforge3\envs\openai\lib\site-packages (from openai) (0.7.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\5-06\miniforge3\envs\openai\lib\site-packages (from openai) (2.10.1)
# Requirement already satisfied: sniffio in c:\users\5-06\miniforge3\envs\openai\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\5-06\miniforge3\envs\openai\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\5-06\miniforge3\envs\openai\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\5-06\miniforge3\envs\openai\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\5-06\miniforge3\envs\openai\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\5-06\miniforge3\envs\openai\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\5-06\miniforge3\envs\openai\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\5-06\miniforge3\envs\openai\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\5-06\miniforge3\envs\openai\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.27.1)
# Requirement already satisfied: colorama in c:\users\5-06\miniforge3\envs\openai\lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
import os
import openai
import pandas as pd
import time

# OpenAI API 키 설정
openai.api_key = os.getenv('OPENAI_API_KEY')

# 입력 및 출력 폴더 경로
input_folder = "C:/fintech_service/핀테크서비스프로젝트/네이버분석전"
output_folder = "C:/fintech_service/핀테크서비스프로젝트/네이버분석후"

# 출력 폴더가 존재하지 않으면 생성
os.makedirs(output_folder, exist_ok=True)

# 입력 폴더의 모든 CSV 파일 가져오기
csv_files = [file for file in os.listdir(input_folder) if file.endswith('.csv')]

# 각 파일에 대해 감성 분석 수행
for csv_file in csv_files:
    input_path = os.path.join(input_folder, csv_file)
    output_path = os.path.join(output_folder, f"{os.path.splitext(csv_file)[0]}_분석.csv")
    
    try:
        # CSV 파일 불러오기
        reviews_df = pd.read_csv(input_path)
        
        # 감성 분석 결과를 저장할 리스트
        sentiments = []

        # 리뷰마다 감성 분석 수행
        for review_text in reviews_df['Review']:  # 컬럼명이 'Review'라고 가정
            retries = 3  # 최대 재시도 횟수
            sentiment = "오류"  # 기본 값

            for attempt in range(retries):
                try:
                    # 최신 ChatCompletion 모델을 사용한 감성 분석
                    response = openai.ChatCompletion.create(
                        model="gpt-3.5-turbo-1106",
                        messages=[
                            {"role": "system", "content": "당신은 감성 분석을 전문으로 하는 도움말 어시스턴트입니다. 문맥이 없는 단어(예: '좋아요', '별로예요')만 있는 경우, 단어의 감성에 따라 '긍정적' 또는 '부정적'으로 응답하세요."},
                            {"role": "user", "content": f"다음 리뷰의 감성을 분석하여 '긍정적' 또는 '부정적' 형식으로만 응답해 주세요: '{review_text}'"}
                        ],
                        max_tokens=20,
                        temperature=0.2
                    )
                    
                    # API 응답에서 감성 분석 결과 추출
                    response_text = response.choices[0].message['content'].strip()
                    if "긍정적" in response_text:
                        sentiment = "긍정적"
                    elif "부정적" in response_text:
                        sentiment = "부정적"
                    else:
                        sentiment = "알 수 없음"
                    
                    break  # 정상 처리되면 반복 종료
                except Exception as e:
                    print(f"리뷰 처리 중 오류 발생 (시도 {attempt + 1}/{retries}): {e}")
                    time.sleep(2)  # 재시도 전 대기

            sentiments.append(sentiment)
            time.sleep(1)  # 요청 간 대기 시간
        
        # 결과를 데이터프레임에 추가
        reviews_df['sentiment'] = sentiments

        # 결과를 파일로 저장
        reviews_df.to_csv(output_path, index=False)
        print(f"감성 분석 완료 및 결과 저장: {output_path}")

    except Exception as e:
        print(f"파일 처리 중 오류 발생: {e}")

print("모든 파일 처리 완료")
# Out:
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\OUR948_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\S카페_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\가정식집밥 세로방_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\고가네철판불백_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\고래똥_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\고품격커피공장 뱅뱅사거리점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\곰바로곰탕_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\곰작골나주곰탕 역삼초교점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\교토일식_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\궁민김밥 본점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\깡돈_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\낙여삼_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\남강매점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\남순남순대국 본점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\노브랜드버거 뱅뱅사거리점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\다슬음 강남점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\더벤티 뱅뱅사거리점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\돼지벅스 강남점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\두두_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\두메 도곡점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\또봉이통닭 서울도곡점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\뚜레쥬르 뱅뱅사거리점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\라망드쉐프_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\리첸_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\만복회해산물 뱅뱅사거리점_reviews_분석.csv
# 리뷰 처리 중 오류 발생 (시도 1/3): The server had an error while processing your request. Sorry about that! {
#   "error": {
#     "message": "The server had an error while processing your request. Sorry about that!",
#     "type": "server_error",
#     "param": null,
#     "code": null
#   }
# } 500 {'error': {'message': 'The server had an error while processing your request. Sorry about that!', 'type': 'server_error', 'param': None, 'code': None}} {'Date': 'Tue, 26 Nov 2024 10:26:39 GMT', 'Content-Type': 'application/json', 'Content-Length': '175', 'Connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-uwybtgkq78cwkdfc9ft9ocky', 'openai-processing-ms': '90136', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '4752', 'x-ratelimit-remaining-tokens': '199890', 'x-ratelimit-reset-requests': '12h35m38.143s', 'x-ratelimit-reset-tokens': '33ms', 'x-request-id': 'req_fecd3956068972e1fa03b7acc86cb444', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'CF-Cache-Status': 'DYNAMIC', 'X-Content-Type-Options': 'nosniff', 'Server': 'cloudflare', 'CF-RAY': '8e892c41ff9dea23-ICN', 'alt-svc': 'h3=":443"; ma=86400'}
# 리뷰 처리 중 오류 발생 (시도 1/3): The server had an error while processing your request. Sorry about that! {
#   "error": {
#     "message": "The server had an error while processing your request. Sorry about that!",
#     "type": "server_error",
#     "param": null,
#     "code": null
#   }
# } 500 {'error': {'message': 'The server had an error while processing your request. Sorry about that!', 'type': 'server_error', 'param': None, 'code': None}} {'Date': 'Tue, 26 Nov 2024 10:29:46 GMT', 'Content-Type': 'application/json', 'Content-Length': '175', 'Connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-uwybtgkq78cwkdfc9ft9ocky', 'openai-processing-ms': '90161', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '4735', 'x-ratelimit-remaining-tokens': '199886', 'x-ratelimit-reset-requests': '12h38m8.499s', 'x-ratelimit-reset-tokens': '33ms', 'x-request-id': 'req_efc48a283e552050c51eddefd7c31fec', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'CF-Cache-Status': 'DYNAMIC', 'X-Content-Type-Options': 'nosniff', 'Server': 'cloudflare', 'CF-RAY': '8e8930d03901aa62-ICN', 'alt-svc': 'h3=":443"; ma=86400'}
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\맥도날드 서초뱅뱅점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\맥켄치킨_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\명동할머니국수 뱅뱅사거리점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\무화잠_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\문화시민 서울_reviews_분석.csv
# 리뷰 처리 중 오류 발생 (시도 1/3): The server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error. (Please include the request ID req_c4aa49724edcbe19a71f85fc7aab4ef9 in your email.) {
#   "error": {
#     "message": "The server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error. (Please include the request ID req_c4aa49724edcbe19a71f85fc7aab4ef9 in your email.)",
#     "type": "server_error",
#     "param": null,
#     "code": null
#   }
# } 500 {'error': {'message': 'The server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error. (Please include the request ID req_c4aa49724edcbe19a71f85fc7aab4ef9 in your email.)', 'type': 'server_error', 'param': None, 'code': None}} {'Date': 'Tue, 26 Nov 2024 11:30:50 GMT', 'Content-Type': 'application/json', 'Content-Length': '369', 'Connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-processing-ms': '50', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '3449', 'x-ratelimit-remaining-tokens': '199826', 'x-ratelimit-reset-requests': '15h43m14.74s', 'x-ratelimit-reset-tokens': '52ms', 'x-request-id': 'req_c4aa49724edcbe19a71f85fc7aab4ef9', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'CF-Cache-Status': 'DYNAMIC', 'X-Content-Type-Options': 'nosniff', 'Server': 'cloudflare', 'CF-RAY': '8e898c7a3caceaa1-ICN', 'alt-svc': 'h3=":443"; ma=86400'}
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\뱅뱅막국수_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\버드나무집 서초동본점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\봉구스밥버거 역삼삼일점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\봉평착한메밀 본점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\봉피양 양재점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\북경반점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\브라운돈까스 뱅뱅사거리점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/핀테크서비스프로젝트/네이버분석후\비채_reviews_분석.csv
# 모든 파일 처리 완료

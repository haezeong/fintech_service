# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 버스정류소현황

# %%
data1 = pd.read_csv("C:/fintech_service/Data/프로젝트/버스정류소현황.csv", encoding='cp949')
data1
# Out:
#        시군명        정류소명                         정류소영문명      정류소id    정류소번호  \
# 0      가평군       3반상회앞                   3-ban Market  239000307  44655.0
# 1      가평군         가는골                      Ganeungol  239000874  44847.0
# 2      가평군         가는골                      Ganeungol  239000875  44848.0
# 3      가평군         가둘기                        Gadulgi  239000061  44280.0
# 4      가평군   가둘기(목동방면)                        Gadulgi  239000459  44354.0
# ...    ...         ...                            ...        ...      ...
# 34580  화성시     흥법리마을회관  Heungbeop-ri Community Center  233002602      NaN
# 34581  화성시      흥법리모래지          Heungbeop-ri Moraeji   233002916      NaN
# 34582  화성시      흥법리모래지          Heungbeop-ri Moraeji   233002603      NaN
# 34583  화성시       흥법사입구                    Heungbeopsa  233000574  36217.0
# 34584  화성시  힐스테이트.호반5차                            NaN  233001620  55490.0
#
#       중앙차로여부     관할관청           위치    WGS84위도     WGS84경도
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34585 entries, 0 to 34584
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   시군명      34585 non-null  object
#  1   정류소명     34585 non-null  object
#  2   정류소영문명   31300 non-null  object
#  3   정류소id    34585 non-null  int64
#  4   정류소번호    31685 non-null  float64
#  5   중앙차로여부   30212 non-null  object
#  6   관할관청     31305 non-null  object
#  7   위치       22463 non-null  object
#  8   WGS84위도  34585 non-null  float64
#  9   WGS84경도  34585 non-null  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.6+ MB

# %%
data1.isna().sum()
# Out:
# 시군명            0
# 정류소명           0
# 정류소영문명      3285
# 정류소id          0
# 정류소번호       2900
# 중앙차로여부      4373
# 관할관청        3280
# 위치         12122
# WGS84위도        0
# WGS84경도        0
# dtype: int64

# %%
data1['시군명'].unique()
# Out:
# array(['가평군', '고양시', '과천시', '광명시', '광주시', '구리시', '군포시', '김포시', '남양주시',
#        '동두천시', '부천시', '성남시', '수원시', '시흥시', '안산시', '안성시', '안양시', '양주시',
#        '양평군', '여주시', '연천군', '오산시', '용인시', '의왕시', '의정부시', '이천시', '파주시',
#        '평택시', '포천시', '하남시', '화성시'], dtype=object)

# %%
data1['정류소id'].nunique()
# Out:
# 34585

# %%
data1 = data1.drop(['정류소영문명','정류소번호','중앙차로여부','관할관청','위치'], axis=1)
data1.head(2)
# Out:
#    시군명   정류소명      정류소id    WGS84위도     WGS84경도
# 0  가평군  3반상회앞  239000307  37.811250  127.521467
# 1  가평군    가는골  239000874  37.967533  127.418617

# %%
data1.isna().sum()
# Out:
# 시군명        0
# 정류소명       0
# 정류소id      0
# WGS84위도    0
# WGS84경도    0
# dtype: int64

# %%
data1.to_csv("C:/fintech_service/Data/프로젝트/버스정류소현황_전처리.csv", index=False)

# %% [markdown]
# # 종합병원현황

# %%
data2 = pd.read_csv("C:/fintech_service/Data/프로젝트/종합병원현황(병원급).csv", encoding='cp949')
data2
# Out:
#      시군명                     사업장명       인허가일자  영업상태명 폐업일자  병상수(개) 의료기관종별명  \
# 0    고양시          의료법인성광의료재단일산차병원  2019-12-26  영업/정상  NaN     260    종합병원
# 1    고양시             국민건강보험공단일산병원  2000-01-18  영업/정상  NaN     850    종합병원
# 2    고양시              동국대학교일산불교병원  2005-05-31  영업/정상  NaN     566    종합병원
# 3    고양시               인제대학교일산백병원  1999-12-06  영업/정상  NaN     645    종합병원
# 4    고양시                    국립암센터  2000-09-08  영업/정상  NaN     550    종합병원
# ..   ...                      ...         ...    ...  ...     ...     ...
# 135  화성시       의료법인 원광의료재단 원광종합병원  2017-06-12  영업/정상  NaN     283    종합병원
# 136  화성시              한림대학교동탄성심병원  2012-09-14  영업/정상  NaN     813    종합병원
# 137  화성시  의료법인 은혜와감사의료재단 화성중앙종합병원  2004-10-30  영업/정상  NaN     139    종합병원
# 138  화성시       의료법인 원광의료재단 원광종합병원  2017-06-12    영업중  NaN     283    종합병원
# 139  화성시              한림대학교동탄성심병원  2012-09-14    영업중  NaN     781    종합병원
#
#      의료인수(명)  입원실수(개)                                             진료과목내용  \
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시군명       140 non-null    object
#  1   사업장명      140 non-null    object
#  2   인허가일자     140 non-null    object
#  3   영업상태명     140 non-null    object
#  4   폐업일자      4 non-null      object
#  5   병상수(개)    140 non-null    int64
#  6   의료기관종별명   140 non-null    object
#  7   의료인수(명)   140 non-null    int64
#  8   입원실수(개)   140 non-null    int64
#  9   진료과목내용    140 non-null    object
#  10  연면적(㎡)    140 non-null    float64
#  11  소재지도로명주소  140 non-null    object
#  12  소재지지번주소   140 non-null    object
#  13  소재지우편번호   140 non-null    int64
#  14  WGS84위도   140 non-null    float64
#  15  WGS84경도   140 non-null    float64
# dtypes: float64(3), int64(4), object(9)
# memory usage: 17.6+ KB

# %%
data2.isna().sum()
# Out:
# 시군명           0
# 사업장명          0
# 인허가일자         0
# 영업상태명         0
# 폐업일자        136
# 병상수(개)        0
# 의료기관종별명       0
# 의료인수(명)       0
# 입원실수(개)       0
# 진료과목내용        0
# 연면적(㎡)        0
# 소재지도로명주소      0
# 소재지지번주소       0
# 소재지우편번호       0
# WGS84위도       0
# WGS84경도       0
# dtype: int64

# %%
data2['영업상태명'].unique()
# Out:
# array(['영업/정상', '영업중', '폐업', '취소/말소/만료/정지/중지'], dtype=object)

# %%
data2['폐업일자'].unique()
# Out:
# array([nan, '2011-01-17', '2023-03-14', '2017-04-25'], dtype=object)

# %%
data2 = data2[data2['폐업일자'].isna()]
data2
# Out:
#      시군명                     사업장명       인허가일자  영업상태명 폐업일자  병상수(개) 의료기관종별명  \
# 0    고양시          의료법인성광의료재단일산차병원  2019-12-26  영업/정상  NaN     260    종합병원
# 1    고양시             국민건강보험공단일산병원  2000-01-18  영업/정상  NaN     850    종합병원
# 2    고양시              동국대학교일산불교병원  2005-05-31  영업/정상  NaN     566    종합병원
# 3    고양시               인제대학교일산백병원  1999-12-06  영업/정상  NaN     645    종합병원
# 4    고양시                    국립암센터  2000-09-08  영업/정상  NaN     550    종합병원
# ..   ...                      ...         ...    ...  ...     ...     ...
# 135  화성시       의료법인 원광의료재단 원광종합병원  2017-06-12  영업/정상  NaN     283    종합병원
# 136  화성시              한림대학교동탄성심병원  2012-09-14  영업/정상  NaN     813    종합병원
# 137  화성시  의료법인 은혜와감사의료재단 화성중앙종합병원  2004-10-30  영업/정상  NaN     139    종합병원
# 138  화성시       의료법인 원광의료재단 원광종합병원  2017-06-12    영업중  NaN     283    종합병원
# 139  화성시              한림대학교동탄성심병원  2012-09-14    영업중  NaN     781    종합병원
#
#      의료인수(명)  입원실수(개)                                             진료과목내용  \
# ...

# %%
data2['폐업일자'].unique()
# Out:
# array([nan], dtype=object)

# %%
data2['영업상태명'].unique()
# Out:
# array(['영업/정상', '영업중'], dtype=object)

# %%
data2['의료기관종별명'].unique()
# Out:
# array(['종합병원'], dtype=object)

# %%
data2.isna().sum()
# Out:
# 시군명           0
# 사업장명          0
# 인허가일자         0
# 영업상태명         0
# 폐업일자        136
# 병상수(개)        0
# 의료기관종별명       0
# 의료인수(명)       0
# 입원실수(개)       0
# 진료과목내용        0
# 연면적(㎡)        0
# 소재지도로명주소      0
# 소재지지번주소       0
# 소재지우편번호       0
# WGS84위도       0
# WGS84경도       0
# dtype: int64

# %%
data2 = data2.drop(['인허가일자','영업상태명','폐업일자','병상수(개)','소재지지번주소'], axis=1)
data2
# Out:
#      시군명                     사업장명 의료기관종별명  의료인수(명)  입원실수(개)  \
# 0    고양시          의료법인성광의료재단일산차병원    종합병원      562      112
# 1    고양시             국민건강보험공단일산병원    종합병원     1581      244
# 2    고양시              동국대학교일산불교병원    종합병원      951      176
# 3    고양시               인제대학교일산백병원    종합병원     1146      141
# 4    고양시                    국립암센터    종합병원     1069      194
# ..   ...                      ...     ...      ...      ...
# 135  화성시       의료법인 원광의료재단 원광종합병원    종합병원       34       65
# 136  화성시              한림대학교동탄성심병원    종합병원     1051      213
# 137  화성시  의료법인 은혜와감사의료재단 화성중앙종합병원    종합병원       84       33
# 138  화성시       의료법인 원광의료재단 원광종합병원    종합병원       34       65
# 139  화성시              한림대학교동탄성심병원    종합병원     1051      213
#
#                                                 진료과목내용     연면적(㎡)  \
# 0    내과, 신경과, 정신건강의학과, 외과, 성형외과, 마취통증의학과, 산부인과, 소아청...   29658.33
# 1    내과, 신경과, 정신건강의학과, 외과, 정형외과, 신경외과, 심장혈관흉부외과, 성형...  112786.91
# ...

# %%
data2.head(2)
# Out:
#    시군명             사업장명 의료기관종별명  의료인수(명)  입원실수(개)  \
# 0  고양시  의료법인성광의료재단일산차병원    종합병원      562      112
# 1  고양시     국민건강보험공단일산병원    종합병원     1581      244
#
#                                               진료과목내용     연면적(㎡)  \
# 0  내과, 신경과, 정신건강의학과, 외과, 성형외과, 마취통증의학과, 산부인과, 소아청...   29658.33
# 1  내과, 신경과, 정신건강의학과, 외과, 정형외과, 신경외과, 심장혈관흉부외과, 성형...  112786.91
#
#                                             소재지도로명주소  소재지우편번호    WGS84위도  \
# 0  경기도 고양시 일산동구 중앙로 1205, 지하1층(일부),지하2층,지하4층(일부),...    10414  37.654123
# 1        경기도 고양시 일산동구 일산로 100 (백석동,백석1동 1241외1필지 4층)    10444  37.645475
#
#       WGS84경도
# 0  126.775740
# 1  126.792963

# %%
data2.isna().sum()
# Out:
# 시군명         0
# 사업장명        0
# 의료기관종별명     0
# 의료인수(명)     0
# 입원실수(개)     0
# 진료과목내용      0
# 연면적(㎡)      0
# 소재지도로명주소    0
# 소재지우편번호     0
# WGS84위도     0
# WGS84경도     0
# dtype: int64

# %%
# data2 = data2[['시군명', '사업장명', '의료기관종별명', '']]

# %%
data2.to_csv("C:/fintech_service/Data/프로젝트/종합병원현황_전처리.csv", index=False)

# %% [markdown]
# # 개인병원 현황

# %%
data3 = pd.read_csv("C:/fintech_service/Data/프로젝트/병원현황(병원급).csv", encoding='cp949')
data3
# Out:
#      시군명                   사업장명  소재지우편번호  \
# 0    가평군             노체리안드리자애병원    12432
# 1    가평군         에이치제이매그놀리아국제병원    12461
# 2    가평군                 국군청평병원    12452
# 3    고양시                 연세마두병원    10414
# 4    고양시                  해븐리병원    10338
# ..   ...                    ...      ...
# 541  화성시     (사)한국장애인케어협회 굿닥터병원  445-310
# 542  화성시    의료법인 녹산의료재단 동수원남양병원  445-010
# 543  화성시                   이화병원    18573
# 544  화성시                동탄플러스병원    18455
# 545  화성시  의료법인 신명진의료재단 퍼스트힐화성병원    18262
#
#                                               소재지도로명주소  \
# 0                     경기도 가평군 조종면 꽃동네길 46 (노체리안드리자애병원)
# 1                             경기도 가평군 설악면 미사리로 267-177
# 2                                  경기도 가평군 청평면 경춘로 926
# 3                    경기도 고양시 일산동구 강석로 123 (마두동, 뉴삼창마트)
# 4     경기도 고양시 일산동구 중산로 117, 지하1층 일부, 1층 일부, 2~5층 (중산동)
# ..                                                 ...
# 541                          경기도 화성시 효행로265번길 16 (기안동)
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546 entries, 0 to 545
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시군명       546 non-null    object
#  1   사업장명      546 non-null    object
#  2   소재지우편번호   543 non-null    object
#  3   소재지도로명주소  540 non-null    object
#  4   소재지지번주소   546 non-null    object
#  5   인허가일자     546 non-null    object
#  6   영업상태명     546 non-null    object
#  7   폐업일자      195 non-null    object
#  8   의료기관종별명   546 non-null    object
#  9   병상수(개)    546 non-null    int64
#  10  의료인수(명)   546 non-null    int64
#  11  입원실수(개)   546 non-null    int64
#  12  진료과목내용    545 non-null    object
#  13  연면적(㎡)    546 non-null    float64
#  14  WGS84위도   542 non-null    float64
#  15  WGS84경도   542 non-null    float64
# dtypes: float64(3), int64(3), object(10)
# memory usage: 68.4+ KB

# %%
data3.isna().sum()
# Out:
# 시군명           0
# 사업장명          0
# 소재지우편번호       3
# 소재지도로명주소      6
# 소재지지번주소       0
# 인허가일자         0
# 영업상태명         0
# 폐업일자        351
# 의료기관종별명       0
# 병상수(개)        0
# 의료인수(명)       0
# 입원실수(개)       0
# 진료과목내용        1
# 연면적(㎡)        0
# WGS84위도       4
# WGS84경도       4
# dtype: int64

# %%
data3['영업상태명'].unique()
# Out:
# array(['영업/정상', '폐업', '영업중', '취소/말소/만료/정지/중지', '휴업'], dtype=object)

# %%
data3['폐업일자'].unique()
# Out:
# array([nan, '2017-09-19', '2016-01-08', '2006-05-08', '1997-07-08',
#        '1999-11-30', '2010-10-13', '2019-06-21', '2023-08-11',
#        '2023-04-20', '2010-11-29', '2009-09-02', '2017-07-31',
#        '2012-07-25', '2010-06-10', '2020-03-09', '2012-02-02',
#        '2004-05-03', '2012-07-16', '2008-09-18', '2008-09-01',
#        '2012-08-10', '2013-04-09', '2020-03-02', '2011-11-22',
#        '2014-11-30', '2012-04-17', '2016-10-31', '2011-07-01',
#        '2020-12-01', '2017-01-02', '2009-02-13', '2015-06-15',
#        '2011-12-30', '2009-10-01', '2015-02-02', '2000-07-31',
#        '2002-02-28', '2005-02-25', '2011-07-29', '2009-08-14',
#        '2009-04-30', '2017-02-10', '2017-06-01', '2007-09-06',
#        '2013-01-17', '2010-12-08', '2009-12-31', '2015-11-12',
#        '2018-04-10', '2024-01-08', '2013-12-09', '2014-05-23',
#        '2015-06-21', '2015-12-29', '2012-12-12', '2022-07-01',
#        '2010-07-01', '2022-03-31', '2015-01-01', '2018-07-11',
# ...

# %%
data3 = data3[data3['폐업일자'].isna()]
data3
# Out:
#      시군명                   사업장명 소재지우편번호  \
# 0    가평군             노체리안드리자애병원   12432
# 1    가평군         에이치제이매그놀리아국제병원   12461
# 3    고양시                 연세마두병원   10414
# 4    고양시                  해븐리병원   10338
# 5    고양시                 원당연세병원   10461
# ..   ...                    ...     ...
# 530  화성시                 동탄성모병원   18505
# 531  화성시                  나이스병원   18313
# 532  화성시                 바르다임병원   18490
# 533  화성시                화성디에스병원   18270
# 545  화성시  의료법인 신명진의료재단 퍼스트힐화성병원   18262
#
#                                               소재지도로명주소  \
# 0                     경기도 가평군 조종면 꽃동네길 46 (노체리안드리자애병원)
# 1                             경기도 가평군 설악면 미사리로 267-177
# 3                    경기도 고양시 일산동구 강석로 123 (마두동, 뉴삼창마트)
# 4     경기도 고양시 일산동구 중산로 117, 지하1층 일부, 1층 일부, 2~5층 (중산동)
# 5                경기도 고양시 덕양구 호국로 781, 2,3,4,6,7층 (주교동)
# ..                                                 ...
# 530    경기도 화성시 동탄순환대로 127-19, 동탄에스비타운 3(일부),6,7층 (산척동)
# ...

# %%
data3['폐업일자'].unique()
# Out:
# array([nan], dtype=object)

# %%
data3['영업상태명'].unique()
# Out:
# array(['영업/정상', '영업중', '휴업', '폐업'], dtype=object)

# %%
data3 = data3[~data3['영업상태명'].isin(['휴업', '폐업'])]
data3
# Out:
#      시군명            사업장명 소재지우편번호  \
# 0    가평군      노체리안드리자애병원   12432
# 1    가평군  에이치제이매그놀리아국제병원   12461
# 3    고양시          연세마두병원   10414
# 4    고양시           해븐리병원   10338
# 5    고양시          원당연세병원   10461
# ..   ...             ...     ...
# 529  화성시            튼튼병원   18379
# 530  화성시          동탄성모병원   18505
# 531  화성시           나이스병원   18313
# 532  화성시          바르다임병원   18490
# 533  화성시         화성디에스병원   18270
#
#                                              소재지도로명주소  \
# 0                    경기도 가평군 조종면 꽃동네길 46 (노체리안드리자애병원)
# 1                            경기도 가평군 설악면 미사리로 267-177
# 3                   경기도 고양시 일산동구 강석로 123 (마두동, 뉴삼창마트)
# 4    경기도 고양시 일산동구 중산로 117, 지하1층 일부, 1층 일부, 2~5층 (중산동)
# 5               경기도 고양시 덕양구 호국로 781, 2,3,4,6,7층 (주교동)
# ..                                                ...
# 529                        경기도 화성시 영통로 66, 3~8층 (반월동)
# 530   경기도 화성시 동탄순환대로 127-19, 동탄에스비타운 3(일부),6,7층 (산척동)
# 531                    경기도 화성시 봉담읍 삼천병마로 1283, 4,5,6층
# ...

# %%
data3['영업상태명'].unique()
# Out:
# array(['영업/정상', '영업중'], dtype=object)

# %%
data3['의료기관종별명'].unique()
# Out:
# array(['병원'], dtype=object)

# %%
data3.isna().sum()
# Out:
# 시군명           0
# 사업장명          0
# 소재지우편번호       0
# 소재지도로명주소      0
# 소재지지번주소       0
# 인허가일자         0
# 영업상태명         0
# 폐업일자        343
# 의료기관종별명       0
# 병상수(개)        0
# 의료인수(명)       0
# 입원실수(개)       0
# 진료과목내용        0
# 연면적(㎡)        0
# WGS84위도       0
# WGS84경도       0
# dtype: int64

# %%
data3 = data3.drop(['소재지지번주소','인허가일자','영업상태명','입원실수(개)','폐업일자'], axis=1)
data3
# Out:
#      시군명            사업장명 소재지우편번호  \
# 0    가평군      노체리안드리자애병원   12432
# 1    가평군  에이치제이매그놀리아국제병원   12461
# 3    고양시          연세마두병원   10414
# 4    고양시           해븐리병원   10338
# 5    고양시          원당연세병원   10461
# ..   ...             ...     ...
# 529  화성시            튼튼병원   18379
# 530  화성시          동탄성모병원   18505
# 531  화성시           나이스병원   18313
# 532  화성시          바르다임병원   18490
# 533  화성시         화성디에스병원   18270
#
#                                              소재지도로명주소 의료기관종별명  병상수(개)  \
# 0                    경기도 가평군 조종면 꽃동네길 46 (노체리안드리자애병원)      병원      62
# 1                            경기도 가평군 설악면 미사리로 267-177      병원      99
# 3                   경기도 고양시 일산동구 강석로 123 (마두동, 뉴삼창마트)      병원     105
# 4    경기도 고양시 일산동구 중산로 117, 지하1층 일부, 1층 일부, 2~5층 (중산동)      병원     178
# 5               경기도 고양시 덕양구 호국로 781, 2,3,4,6,7층 (주교동)      병원      68
# ..                                                ...     ...     ...
# ...

# %%
data3.head(2)
# Out:
#    시군명            사업장명 소재지우편번호                          소재지도로명주소 의료기관종별명  \
# 0  가평군      노체리안드리자애병원   12432  경기도 가평군 조종면 꽃동네길 46 (노체리안드리자애병원)      병원
# 1  가평군  에이치제이매그놀리아국제병원   12461          경기도 가평군 설악면 미사리로 267-177      병원
#
#    병상수(개)  의료인수(명)                                             진료과목내용  \
# 0      62       16                             내과, 정신건강의학과, 외과, 영상의학과
# 1      99       51  내과, 신경과, 정신건강의학과, 외과, 정형외과, 성형외과, 마취통증의학과, 산부인...
#
#      연면적(㎡)    WGS84위도     WGS84경도
# 0   6511.34  37.884883  127.351696
# 1  22941.69  37.691127  127.521381

# %%
data3.isna().sum()
# Out:
# 시군명         0
# 사업장명        0
# 소재지우편번호     0
# 소재지도로명주소    0
# 의료기관종별명     0
# 병상수(개)      0
# 의료인수(명)     0
# 진료과목내용      0
# 연면적(㎡)      0
# WGS84위도     0
# WGS84경도     0
# dtype: int64

# %%
data3.to_csv("C:/fintech_service/Data/프로젝트/개인병원현황_전처리.csv", index=False)

# %% [markdown]
# # 초중고등학교 현황

# %%
data4 = pd.read_csv("C:/fintech_service/Data/프로젝트/초중고등학교현황.csv", encoding='cp949')
data4
# Out:
#      학교구분명 공사립구분명       시설명           전화번호                  소재지지번주소  \
# 0     초등학교     공립  다산별빛초등학교   031-540-7500      경기도 남양주시 다산동 6112번지
# 1     초등학교     공립    다율초등학교   031-550-0900       경기도 파주시 다율동 1011번지
# 2     초등학교     공립    원흥초등학교   031-969-5610    경기도 고양시 덕양구 원흥동 618번지
# 3     초등학교     공립  평택모산초등학교   031-686-1401              경기도 평택시 동삭동
# 4     초등학교     공립  시흥가온초등학교   031-364-1700        경기도 시흥시 장현동 595번지
# ...    ...    ...       ...            ...                      ...
# 2475  고등학교     사립    덕영고등학교   031-329-4300  경기도 용인시 처인구 고림동 737-1번지
# 2476  고등학교     공립    용호고등학교   031-390-4464         경기도 군포시 당동 875번지
# 2477  고등학교     사립    우성고등학교   031-3619-200        경기도 의왕시 고천동 496번지
# 2478  고등학교     공립    원곡고등학교  031-8085-0008  경기도 안산시 단원구 원곡동 965-1번지
# 2479  고등학교     공립    원미고등학교   032-722-6200    경기도 부천시 원미구 중동 1098번지
#
#                     소재지도로명주소  소재지우편번호    WGS84위도     WGS84경도
# 0     경기도 남양주시 다산중앙로82번안길 40  12249.0  37.617338  127.164868
# ...

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2480 entries, 0 to 2479
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   학교구분명     2480 non-null   object
#  1   공사립구분명    2480 non-null   object
#  2   시설명       2480 non-null   object
#  3   전화번호      2480 non-null   object
#  4   소재지지번주소   2480 non-null   object
#  5   소재지도로명주소  2452 non-null   object
#  6   소재지우편번호   2458 non-null   float64
#  7   WGS84위도   2454 non-null   float64
#  8   WGS84경도   2454 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 174.5+ KB

# %%
data4.isna().sum()
# Out:
# 학교구분명        0
# 공사립구분명       0
# 시설명          0
# 전화번호         0
# 소재지지번주소      0
# 소재지도로명주소    28
# 소재지우편번호     22
# WGS84위도     26
# WGS84경도     26
# dtype: int64

# %%
data4['소재지우편번호'] = data4['소재지우편번호'].astype(str).str[:5]
data4
# Out:
#      학교구분명 공사립구분명       시설명           전화번호                  소재지지번주소  \
# 0     초등학교     공립  다산별빛초등학교   031-540-7500      경기도 남양주시 다산동 6112번지
# 1     초등학교     공립    다율초등학교   031-550-0900       경기도 파주시 다율동 1011번지
# 2     초등학교     공립    원흥초등학교   031-969-5610    경기도 고양시 덕양구 원흥동 618번지
# 3     초등학교     공립  평택모산초등학교   031-686-1401              경기도 평택시 동삭동
# 4     초등학교     공립  시흥가온초등학교   031-364-1700        경기도 시흥시 장현동 595번지
# ...    ...    ...       ...            ...                      ...
# 2475  고등학교     사립    덕영고등학교   031-329-4300  경기도 용인시 처인구 고림동 737-1번지
# 2476  고등학교     공립    용호고등학교   031-390-4464         경기도 군포시 당동 875번지
# 2477  고등학교     사립    우성고등학교   031-3619-200        경기도 의왕시 고천동 496번지
# 2478  고등학교     공립    원곡고등학교  031-8085-0008  경기도 안산시 단원구 원곡동 965-1번지
# 2479  고등학교     공립    원미고등학교   032-722-6200    경기도 부천시 원미구 중동 1098번지
#
#                     소재지도로명주소 소재지우편번호    WGS84위도     WGS84경도
# 0     경기도 남양주시 다산중앙로82번안길 40   12249  37.617338  127.164868
# ...

# %%
missing_rows = data4[data4.isna().any(axis=1)]
missing_rows
# Out:
#      학교구분명 공사립구분명        시설명           전화번호                           소재지지번주소  \
# 21    초등학교     공립     건원초등학교   031-567-9410                   경기도 구리시 동구릉로 80
# 72    초등학교     공립     신현초등학교   031-776-8300               경기도 광주시 오포읍 신현로12번길
# 100   초등학교     공립    도래울초등학교   031-963-6896                 경기도 고양시 덕양구 도래울3로
# 143   초등학교     공립   미사강변초등학교  031-8026-0680               경기도 하남시 미사강변북로 55번길
# 158   초등학교     공립     보름초등학교  031-5186-1600               경기도 김포시 고촌읍 수기로 106
# 160   초등학교     공립     이의초등학교  031-8006-1800               경기도 수원시 영통구 법조로 150
# 282   초등학교     공립     용정초등학교   031-967-0366              경기도 고양시 덕양구 은빛로17번길
# 400   초등학교     공립   안산창촌초등학교   031-502-1166       경기도 안산시 상록구 건건동 665번지 서해아파트
# 425   초등학교     공립     화창초등학교   031-474-0019               경기도 안양시 만안구 양화로 217
# 450   초등학교     공립   성남제일초등학교   031-746-6712         경기도 성남시 중원구 중앙동 광명로 184번길
# 504   초등학교     공립     보라초등학교   031-282-2770               경기도 용인시 기흥구 금화로 105
# ...

# %%
data4.isna().sum()
# Out:
# 학교구분명        0
# 공사립구분명       0
# 시설명          0
# 전화번호         0
# 소재지지번주소      0
# 소재지도로명주소    28
# 소재지우편번호      0
# WGS84위도     26
# WGS84경도     26
# dtype: int64

# %%
data4 = data4.drop(['소재지도로명주소'], axis=1)
data4
# Out:
#      학교구분명 공사립구분명       시설명           전화번호                  소재지지번주소 소재지우편번호  \
# 0     초등학교     공립  다산별빛초등학교   031-540-7500      경기도 남양주시 다산동 6112번지   12249
# 1     초등학교     공립    다율초등학교   031-550-0900       경기도 파주시 다율동 1011번지   10865
# 2     초등학교     공립    원흥초등학교   031-969-5610    경기도 고양시 덕양구 원흥동 618번지   10563
# 3     초등학교     공립  평택모산초등학교   031-686-1401              경기도 평택시 동삭동   18028
# 4     초등학교     공립  시흥가온초등학교   031-364-1700        경기도 시흥시 장현동 595번지   14996
# ...    ...    ...       ...            ...                      ...     ...
# 2475  고등학교     사립    덕영고등학교   031-329-4300  경기도 용인시 처인구 고림동 737-1번지   17151
# 2476  고등학교     공립    용호고등학교   031-390-4464         경기도 군포시 당동 875번지   15876
# 2477  고등학교     사립    우성고등학교   031-3619-200        경기도 의왕시 고천동 496번지   16062
# 2478  고등학교     공립    원곡고등학교  031-8085-0008  경기도 안산시 단원구 원곡동 965-1번지   15364
# 2479  고등학교     공립    원미고등학교   032-722-6200    경기도 부천시 원미구 중동 1098번지   14575
#
#         WGS84위도     WGS84경도
# ...

# %%
data4.head(2)
# Out:
#   학교구분명 공사립구분명       시설명          전화번호              소재지지번주소 소재지우편번호  \
# 0  초등학교     공립  다산별빛초등학교  031-540-7500  경기도 남양주시 다산동 6112번지   12249
# 1  초등학교     공립    다율초등학교  031-550-0900   경기도 파주시 다율동 1011번지   10865
#
#      WGS84위도     WGS84경도
# 0  37.617338  127.164868
# 1  37.738022  126.726780

# %%
data4.isna().sum()
# Out:
# 학교구분명       0
# 공사립구분명      0
# 시설명         0
# 전화번호        0
# 소재지지번주소     0
# 소재지우편번호     0
# WGS84위도    26
# WGS84경도    26
# dtype: int64

# %%
data4.to_csv("C:/fintech_service/Data/프로젝트/초중고등학교현황_전처리.csv", index=False)

# %% [markdown]
# # 유치원 현황

# %%
data5 = pd.read_csv("C:/fintech_service/Data/프로젝트/유치원현황.csv", encoding='cp949')
data5
# Out:
#         교육청명   교육지원청명         유치원명    설립유형 대표자명 유치원장명       설립일      개업일자  \
# 0     경기도교육청  파주교육지원청  자유초등학교병설유치원  공립(병설)  노치삼   노치삼  20110301  20110301
# 1     경기도교육청  파주교육지원청  신산초등학교병설유치원  공립(병설)  한석주   한석주  19801226  19810310
# 2     경기도교육청  파주교육지원청  장파초등학교병설유치원  공립(병설)  용을미   용을미  19801230  19810301
# 3     경기도교육청  파주교육지원청  운광초등학교병설유치원  공립(병설)  이현순   이현순  20100309  20100309
# 4     경기도교육청  수원교육지원청  율전초등학교병설유치원  공립(병설)  김선영   김선영  20090221  20090305
# ...      ...      ...          ...     ...  ...   ...       ...       ...
# 2212  경기도교육청  포천교육지원청  이곡초등학교병설유치원  공립(병설)  김유태   김유태  19830301  19830301
# 2213  경기도교육청  포천교육지원청  영평초등학교병설유치원  공립(병설)  박찬욱   박찬욱  19810301  19810301
# 2214  경기도교육청  포천교육지원청  포담초등학교병설유치원  공립(병설)  송상미   송상미  20220302  20220302
# 2215  경기도교육청  양평교육지원청  양서초등학교병설유치원  공립(병설)  김기동   김기동  20100301  20100301
# 2216  경기도교육청  양평교육지원청        성림유치원  사립(사인)  강진희   이화영  19811127  19820301
#
#               전화번호                            홈페이지주소  ... 4세영유아수  5세영유아수  \
# ...

# %%
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2217 entries, 0 to 2216
# Data columns (total 33 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   교육청명       2217 non-null   object
#  1   교육지원청명     2217 non-null   object
#  2   유치원명       2217 non-null   object
#  3   설립유형       2217 non-null   object
#  4   대표자명       2217 non-null   object
#  5   유치원장명      2217 non-null   object
#  6   설립일        2217 non-null   int64
#  7   개업일자       2217 non-null   int64
#  8   전화번호       2217 non-null   object
#  9   홈페이지주소     1218 non-null   object
#  10  운영시간       2217 non-null   object
#  11  3세학급수      1372 non-null   float64
#  12  4세학급수      1491 non-null   float64
#  13  5세학급수      1703 non-null   float64
#  14  혼합학급수      2217 non-null   int64
#  15  특수학급수      341 non-null    float64
#  16  인가총정원수     2217 non-null   int64
#  17  3세모집정원수    1372 non-null   float64
#  18  4세모집정원수    1491 non-null   float64
# ...

# %%
data5.isna().sum()
# Out:
# 교육청명            0
# 교육지원청명          0
# 유치원명            0
# 설립유형            0
# 대표자명            0
# 유치원장명           0
# 설립일             0
# 개업일자            0
# 전화번호            0
# 홈페이지주소        999
# 운영시간            0
# 3세학급수         845
# 4세학급수         726
# 5세학급수         514
# 혼합학급수           0
# 특수학급수        1876
# 인가총정원수          0
# 3세모집정원수       845
# 4세모집정원수       726
# 5세모집정원수       514
# 혼합모집정원수         0
# 특수학급모집정원수    1876
# 3세영유아수        845
# 4세영유아수        726
# 5세영유아수        514
# 혼합영유아수          0
# 특수영유아수       1876
# 공시차수            0
# 정제도로명주소       200
# 정제지번주소          0
# 정제우편번호          8
# 정제WGS84위도      15
# 정제WGS84경도      15
# dtype: int64

# %%
data5['교육청명'].unique()
# Out:
# array(['경기도교육청'], dtype=object)

# %%
data5 = data5.drop(['교육청명','교육지원청명','대표자명','유치원장명','설립일','개업일자','홈페이지주소','3세모집정원수','4세모집정원수','5세모집정원수','혼합모집정원수','특수학급모집정원수','공시차수'], axis=1)
data5.head(2)
# Out:
#           유치원명    설립유형          전화번호           운영시간  3세학급수  4세학급수  5세학급수  \
# 0  자유초등학교병설유치원  공립(병설)  031-954-3815  09시00분~17시00분    1.0    1.0    1.0
# 1  신산초등학교병설유치원  공립(병설)  031-947-4179  09시00분~17시00분    NaN    NaN    NaN
#
#    혼합학급수  특수학급수  인가총정원수  3세영유아수  4세영유아수  5세영유아수  혼합영유아수  특수영유아수  \
# 0      0    1.0      64     5.0     9.0    19.0       0     4.0
# 1      1    NaN      20     NaN     NaN     NaN      10     NaN
#
#                 정제도로명주소                 정제지번주소   정제우편번호  정제WGS84위도   정제WGS84경도
# 0  경기도 파주시 문산읍 방촌로 1722  경기도 파주시 문산읍 당동리 939번지  10815.0  37.865537  126.786557
# 1    경기도 파주시 광탄면 심궁로 13  경기도 파주시 광탄면 신산리 199번지  10948.0  37.780590  126.852319

# %%
data5 = data5.drop(['전화번호','3세학급수','4세학급수','5세학급수','혼합학급수','특수학급수'], axis=1)
data5.head(2)
# Out:
#           유치원명    설립유형           운영시간  인가총정원수  3세영유아수  4세영유아수  5세영유아수  혼합영유아수  \
# 0  자유초등학교병설유치원  공립(병설)  09시00분~17시00분      64     5.0     9.0    19.0       0
# 1  신산초등학교병설유치원  공립(병설)  09시00분~17시00분      20     NaN     NaN     NaN      10
#
#    특수영유아수               정제도로명주소                 정제지번주소   정제우편번호  정제WGS84위도  \
# 0     4.0  경기도 파주시 문산읍 방촌로 1722  경기도 파주시 문산읍 당동리 939번지  10815.0  37.865537
# 1     NaN    경기도 파주시 광탄면 심궁로 13  경기도 파주시 광탄면 신산리 199번지  10948.0  37.780590
#
#     정제WGS84경도
# 0  126.786557
# 1  126.852319

# %%
data5 = data5.drop(['3세영유아수','4세영유아수','5세영유아수','혼합영유아수','특수영유아수'], axis=1)
data5.head(2)
# Out:
#           유치원명    설립유형           운영시간  인가총정원수               정제도로명주소  \
# 0  자유초등학교병설유치원  공립(병설)  09시00분~17시00분      64  경기도 파주시 문산읍 방촌로 1722
# 1  신산초등학교병설유치원  공립(병설)  09시00분~17시00분      20    경기도 파주시 광탄면 심궁로 13
#
#                   정제지번주소   정제우편번호  정제WGS84위도   정제WGS84경도
# 0  경기도 파주시 문산읍 당동리 939번지  10815.0  37.865537  126.786557
# 1  경기도 파주시 광탄면 신산리 199번지  10948.0  37.780590  126.852319

# %%
data5.isna().sum()
# Out:
# 유치원명           0
# 설립유형           0
# 운영시간           0
# 인가총정원수         0
# 정제도로명주소      200
# 정제지번주소         0
# 정제우편번호         8
# 정제WGS84위도     15
# 정제WGS84경도     15
# dtype: int64

# %%
data5 = data5.drop(['정제도로명주소'], axis=1)
data5.head(2)
# Out:
#           유치원명    설립유형           운영시간  인가총정원수                 정제지번주소   정제우편번호  \
# 0  자유초등학교병설유치원  공립(병설)  09시00분~17시00분      64  경기도 파주시 문산읍 당동리 939번지  10815.0
# 1  신산초등학교병설유치원  공립(병설)  09시00분~17시00분      20  경기도 파주시 광탄면 신산리 199번지  10948.0
#
#    정제WGS84위도   정제WGS84경도
# 0  37.865537  126.786557
# 1  37.780590  126.852319

# %%
data5['정제우편번호'] = data5['정제우편번호'].astype(str).str[:5]
data5
# Out:
#              유치원명    설립유형           운영시간  인가총정원수                   정제지번주소  \
# 0     자유초등학교병설유치원  공립(병설)  09시00분~17시00분      64    경기도 파주시 문산읍 당동리 939번지
# 1     신산초등학교병설유치원  공립(병설)  09시00분~17시00분      20    경기도 파주시 광탄면 신산리 199번지
# 2     장파초등학교병설유치원  공립(병설)  09시00분~17시00분      20  경기도 파주시 파평면 장파리 348-1번지
# 3     운광초등학교병설유치원  공립(병설)  08시30분~16시30분      64       경기도 파주시 동패동 1769번지
# 4     율전초등학교병설유치원  공립(병설)  09시00분~17시00분      20  경기도 수원시 장안구 율전동 308-6번지
# ...           ...     ...            ...     ...                      ...
# 2212  이곡초등학교병설유치원  공립(병설)  09시00분~17시00분      20    경기도 포천시 소흘읍 이곡리 200번지
# 2213  영평초등학교병설유치원  공립(병설)  08시40분~16시40분      20    경기도 포천시 영중면 영평리 240번지
# 2214  포담초등학교병설유치원  공립(병설)  09시00분~17시00분      22  경기도 포천시 영중면 성동리 891-3번지
# 2215  양서초등학교병설유치원  공립(병설)  09시00분~17시00분      20  경기도 양평군 양서면 도곡리 320-1번지
# 2216        성림유치원  사립(사인)  08시00분~18시30분      80  경기도 양평군 양평읍 공흥리 788-2번지
#
#      정제우편번호  정제WGS84위도   정제WGS84경도
# 0     10815  37.865537  126.786557
# ...

# %%
data5.head(2)
# Out:
#           유치원명    설립유형           운영시간  인가총정원수                 정제지번주소 정제우편번호  \
# 0  자유초등학교병설유치원  공립(병설)  09시00분~17시00분      64  경기도 파주시 문산읍 당동리 939번지  10815
# 1  신산초등학교병설유치원  공립(병설)  09시00분~17시00분      20  경기도 파주시 광탄면 신산리 199번지  10948
#
#    정제WGS84위도   정제WGS84경도
# 0  37.865537  126.786557
# 1  37.780590  126.852319

# %%
data5.isna().sum()
# Out:
# 유치원명          0
# 설립유형          0
# 운영시간          0
# 인가총정원수        0
# 정제지번주소        0
# 정제우편번호        0
# 정제WGS84위도    15
# 정제WGS84경도    15
# dtype: int64

# %%
data5.to_csv("C:/fintech_service/Data/프로젝트/유치원현황_전처리.csv", index=False)

# %% [markdown]
# # 어린이집 현황

# %%
data6 = pd.read_excel("C:/fintech_service/Data/프로젝트/어린이집기본정보조회(정기)-기준일(20240930).xls")
data6
# Out:
#         시도      시군구       어린이집명 어린이집유형구분 운영현황     우편번호  \
# 0      경기도  고양시일산서구      우성어린이집       가정   폐지  10371.0
# 1      경기도  고양시일산동구     사랑인어린이집       가정   폐지  10357.0
# 2      경기도  고양시일산동구  해맑은아이 어린이집       가정   폐지  10311.0
# 3      경기도   고양시덕양구      솔비어린이집       가정   정상  10530.0
# 4      경기도   고양시덕양구    햇살영아어린이집       가정   폐지  10483.0
# ...    ...      ...         ...      ...  ...      ...
# 17718  경기도      양평군    가온써밋어린이집       민간   정상  12553.0
# 17719  경기도      양평군  해피키즈어반어린이집       민간   정상  12562.0
# 17720  경기도      양평군    한라소담어린이집      국공립   정상  12551.0
# 17721  경기도      양평군    한라별숲어린이집      국공립   정상  12551.0
# 17722  경기도      양평군   반도유보라어린이집      국공립   정상  12519.0
#
#                                                       주소      어린이집전화번호  \
# 0      경기도 고양시 일산서구 대산로 184 101동 103호(주엽동, 문촌마을우성1단지아파트)  031-811-3484
# 1                                경기도 고양시 일산동구 산두로 269-4   031-917-5833
# 2      경기도 고양시 일산동구 하늘마을1로 23 508동 103호(중산동, 하늘마을주공휴먼...  031-919-2212
# ...

# %%
data6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17723 entries, 0 to 17722
# Data columns (total 24 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시도        17723 non-null  object
#  1   시군구       17723 non-null  object
#  2   어린이집명     17723 non-null  object
#  3   어린이집유형구분  17723 non-null  object
#  4   운영현황      17723 non-null  object
#  5   우편번호      17721 non-null  float64
#  6   주소        17723 non-null  object
#  7   어린이집전화번호  17723 non-null  object
#  8   어린이집팩스번호  17723 non-null  object
#  9   보육실수      17723 non-null  int64
#  10  보육실면적     17723 non-null  int64
#  11  놀이터수      17723 non-null  int64
#  12  CCTV설치수   17723 non-null  int64
#  13  보육교직원수    17723 non-null  int64
#  14  정원수       17723 non-null  int64
#  15  현원수       17723 non-null  int64
#  16  위도        16844 non-null  float64
#  17  경도        16844 non-null  float64
#  18  통학차량운영여부  16697 non-null  object
#  19  홈페이지주소    2940 non-null   object
# ...

# %%
data6.isna().sum()
# Out:
# 시도              0
# 시군구             0
# 어린이집명           0
# 어린이집유형구분        0
# 운영현황            0
# 우편번호            2
# 주소              0
# 어린이집전화번호        0
# 어린이집팩스번호        0
# 보육실수            0
# 보육실면적           0
# 놀이터수            0
# CCTV설치수         0
# 보육교직원수          0
# 정원수             0
# 현원수             0
# 위도            879
# 경도            879
# 통학차량운영여부     1026
# 홈페이지주소      14783
# 인가일자           13
# 휴지시작일자      17584
# 휴지종료일자      17587
# 폐지일자         8626
# dtype: int64

# %%
data6['운영현황'].unique()
# Out:
# array(['폐지', '정상', '휴지', '재개'], dtype=object)

# %%
data6[['운영현황', '휴지시작일자', '휴지종료일자','폐지일자']]
# Out:
#       운영현황 휴지시작일자 휴지종료일자        폐지일자
# 0       폐지    NaN    NaN  2015-08-13
# 1       폐지    NaN    NaN  2015-03-30
# 2       폐지    NaN    NaN  2017-11-13
# 3       정상    NaN    NaN         NaN
# 4       폐지    NaN    NaN  2019-03-21
# ...    ...    ...    ...         ...
# 17718   정상    NaN    NaN         NaN
# 17719   정상    NaN    NaN         NaN
# 17720   정상    NaN    NaN         NaN
# 17721   정상    NaN    NaN         NaN
# 17722   정상    NaN    NaN         NaN
#
# [17723 rows x 4 columns]

# %%
paused_data = data6[data6['운영현황'] == '휴지'][['운영현황', '휴지시작일자', '휴지종료일자']]
paused_data
# Out:
#       운영현황      휴지시작일자      휴지종료일자
# 135     휴지  2024-03-15  2024-11-30
# 570     휴지  2024-07-01  2025-06-30
# 696     휴지  2023-12-15  2024-12-13
# 953     휴지  2023-11-01  2024-10-31
# 1101    휴지  2023-03-01  2025-02-28
# ...    ...         ...         ...
# 17408   휴지  2024-07-01  2025-06-30
# 17546   휴지  2016-01-01  2016-12-31
# 17548   휴지  2024-03-04  2025-02-28
# 17563   휴지  2009-03-06         NaN
# 17662   휴지  2024-09-03  2025-02-28
#
# [140 rows x 3 columns]

# %%
paused_data.isna().sum()
# Out:
# 운영현황      0
# 휴지시작일자    1
# 휴지종료일자    4
# dtype: int64

# %%
paused_data[paused_data['휴지시작일자'].isna()]
# Out:
#      운영현황 휴지시작일자 휴지종료일자
# 3426   휴지    NaN    NaN

# %%
paused_data[paused_data['휴지종료일자'].isna()]
# Out:
#       운영현황      휴지시작일자 휴지종료일자
# 3426    휴지         NaN    NaN
# 3428    휴지  2009-03-25    NaN
# 4298    휴지  2009-07-29    NaN
# 17563   휴지  2009-03-06    NaN

# %%
data6 = data6[~((data6['운영현황'] == '휴지') & (data6['휴지종료일자'].isna()))]
data6
# Out:
#         시도      시군구       어린이집명 어린이집유형구분 운영현황     우편번호  \
# 0      경기도  고양시일산서구      우성어린이집       가정   폐지  10371.0
# 1      경기도  고양시일산동구     사랑인어린이집       가정   폐지  10357.0
# 2      경기도  고양시일산동구  해맑은아이 어린이집       가정   폐지  10311.0
# 3      경기도   고양시덕양구      솔비어린이집       가정   정상  10530.0
# 4      경기도   고양시덕양구    햇살영아어린이집       가정   폐지  10483.0
# ...    ...      ...         ...      ...  ...      ...
# 17718  경기도      양평군    가온써밋어린이집       민간   정상  12553.0
# 17719  경기도      양평군  해피키즈어반어린이집       민간   정상  12562.0
# 17720  경기도      양평군    한라소담어린이집      국공립   정상  12551.0
# 17721  경기도      양평군    한라별숲어린이집      국공립   정상  12551.0
# 17722  경기도      양평군   반도유보라어린이집      국공립   정상  12519.0
#
#                                                       주소      어린이집전화번호  \
# 0      경기도 고양시 일산서구 대산로 184 101동 103호(주엽동, 문촌마을우성1단지아파트)  031-811-3484
# 1                                경기도 고양시 일산동구 산두로 269-4   031-917-5833
# 2      경기도 고양시 일산동구 하늘마을1로 23 508동 103호(중산동, 하늘마을주공휴먼...  031-919-2212
# ...

# %%
data6 = data6[~data6['운영현황'].isin(['폐지'])]
data6
# Out:
#         시도      시군구       어린이집명 어린이집유형구분 운영현황     우편번호  \
# 3      경기도   고양시덕양구      솔비어린이집       가정   정상  10530.0
# 5      경기도  고양시일산서구      미소어린이집       가정   정상  10376.0
# 7      경기도   고양시덕양구   신임마누엘어린이집       민간   정상  10275.0
# 9      경기도      양주시      신우어린이집       가정   정상  11444.0
# 22     경기도  고양시일산동구  고양시립저현어린이집      국공립   정상  10323.0
# ...    ...      ...         ...      ...  ...      ...
# 17718  경기도      양평군    가온써밋어린이집       민간   정상  12553.0
# 17719  경기도      양평군  해피키즈어반어린이집       민간   정상  12562.0
# 17720  경기도      양평군    한라소담어린이집      국공립   정상  12551.0
# 17721  경기도      양평군    한라별숲어린이집      국공립   정상  12551.0
# 17722  경기도      양평군   반도유보라어린이집      국공립   정상  12519.0
#
#                                                       주소      어린이집전화번호  \
# 3          경기도 고양시 덕양구 소만로 19 612동 102호(행신동, 소만마을6단지아파트)  031-819-5990
# 5      경기도 고양시 일산서구 대산로 249 106동 102호(대화동, 성저마을동익1단지아파트)  031-814-2577
# 7                           경기도 고양시 덕양구 혜음로13번길 34 (고양동)  031-969-8704
# ...

# %%
data6['운영현황'].unique()
# Out:
# array(['정상', '휴지', '재개'], dtype=object)

# %%
data6.isna().sum()
# Out:
# 시도             0
# 시군구            0
# 어린이집명          0
# 어린이집유형구분       0
# 운영현황           0
# 우편번호           1
# 주소             0
# 어린이집전화번호       0
# 어린이집팩스번호       0
# 보육실수           0
# 보육실면적          0
# 놀이터수           0
# CCTV설치수        0
# 보육교직원수         0
# 정원수            0
# 현원수            0
# 위도             1
# 경도             1
# 통학차량운영여부      32
# 홈페이지주소      7099
# 인가일자           0
# 휴지시작일자      8437
# 휴지종료일자      8437
# 폐지일자        8573
# dtype: int64

# %%
data6 = data6.dropna(subset=['우편번호'])
data6
# Out:
#         시도      시군구       어린이집명 어린이집유형구분 운영현황     우편번호  \
# 3      경기도   고양시덕양구      솔비어린이집       가정   정상  10530.0
# 5      경기도  고양시일산서구      미소어린이집       가정   정상  10376.0
# 7      경기도   고양시덕양구   신임마누엘어린이집       민간   정상  10275.0
# 9      경기도      양주시      신우어린이집       가정   정상  11444.0
# 22     경기도  고양시일산동구  고양시립저현어린이집      국공립   정상  10323.0
# ...    ...      ...         ...      ...  ...      ...
# 17718  경기도      양평군    가온써밋어린이집       민간   정상  12553.0
# 17719  경기도      양평군  해피키즈어반어린이집       민간   정상  12562.0
# 17720  경기도      양평군    한라소담어린이집      국공립   정상  12551.0
# 17721  경기도      양평군    한라별숲어린이집      국공립   정상  12551.0
# 17722  경기도      양평군   반도유보라어린이집      국공립   정상  12519.0
#
#                                                       주소      어린이집전화번호  \
# 3          경기도 고양시 덕양구 소만로 19 612동 102호(행신동, 소만마을6단지아파트)  031-819-5990
# 5      경기도 고양시 일산서구 대산로 249 106동 102호(대화동, 성저마을동익1단지아파트)  031-814-2577
# 7                           경기도 고양시 덕양구 혜음로13번길 34 (고양동)  031-969-8704
# ...

# %%
data6 = data6.drop(['시도','어린이집전화번호','보육실수','어린이집팩스번호','놀이터수','CCTV설치수','정원수','홈페이지주소','인가일자','휴지시작일자','폐지일자'], axis=1)
data6
# Out:
#            시군구       어린이집명 어린이집유형구분 운영현황     우편번호  \
# 3       고양시덕양구      솔비어린이집       가정   정상  10530.0
# 5      고양시일산서구      미소어린이집       가정   정상  10376.0
# 7       고양시덕양구   신임마누엘어린이집       민간   정상  10275.0
# 9          양주시      신우어린이집       가정   정상  11444.0
# 22     고양시일산동구  고양시립저현어린이집      국공립   정상  10323.0
# ...        ...         ...      ...  ...      ...
# 17718      양평군    가온써밋어린이집       민간   정상  12553.0
# 17719      양평군  해피키즈어반어린이집       민간   정상  12562.0
# 17720      양평군    한라소담어린이집      국공립   정상  12551.0
# 17721      양평군    한라별숲어린이집      국공립   정상  12551.0
# 17722      양평군   반도유보라어린이집      국공립   정상  12519.0
#
#                                                       주소  보육실면적  보육교직원수  현원수  \
# 3          경기도 고양시 덕양구 소만로 19 612동 102호(행신동, 소만마을6단지아파트)     45       7   14
# 5      경기도 고양시 일산서구 대산로 249 106동 102호(대화동, 성저마을동익1단지아파트)     54       5   15
# 7                           경기도 고양시 덕양구 혜음로13번길 34 (고양동)    689      29   71
# ...

# %%
data6.isna().sum()
# Out:
# 시군구            0
# 어린이집명          0
# 어린이집유형구분       0
# 운영현황           0
# 우편번호           0
# 주소             0
# 보육실면적          0
# 보육교직원수         0
# 현원수            0
# 위도             1
# 경도             1
# 통학차량운영여부      32
# 휴지종료일자      8436
# dtype: int64

# %%
data6[data6['위도'].isna() | data6['경도'].isna()]
# Out:
#        시군구       어린이집명 어린이집유형구분 운영현황      우편번호                   주소  보육실면적  \
# 2398  남양주시  지금동꿈동산어린이집       가정   휴지  472080.0  경기 남양주시 지금동 129-47       1
#
#       보육교직원수  현원수  위도  경도 통학차량운영여부      휴지종료일자
# 2398       0    0 NaN NaN      NaN  2011-03-03

# %%
data6.loc[:, '우편번호'] = data6['우편번호'].astype(str).str[:5]
data6
# Out:
# C:\Users\5-06\AppData\Local\Temp\ipykernel_15400\1657418390.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['10530' '10376' '10275' ... '12551' '12551' '12519']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data6.loc[:, '우편번호'] = data6['우편번호'].astype(str).str[:5]
#            시군구       어린이집명 어린이집유형구분 운영현황   우편번호  \
# 3       고양시덕양구      솔비어린이집       가정   정상  10530
# 5      고양시일산서구      미소어린이집       가정   정상  10376
# 7       고양시덕양구   신임마누엘어린이집       민간   정상  10275
# 9          양주시      신우어린이집       가정   정상  11444
# 22     고양시일산동구  고양시립저현어린이집      국공립   정상  10323
# ...        ...         ...      ...  ...    ...
# 17718      양평군    가온써밋어린이집       민간   정상  12553
# 17719      양평군  해피키즈어반어린이집       민간   정상  12562
# 17720      양평군    한라소담어린이집      국공립   정상  12551
# 17721      양평군    한라별숲어린이집      국공립   정상  12551
# 17722      양평군   반도유보라어린이집      국공립   정상  12519
#
# ...

# %%
from datetime import datetime
# 오늘 날짜
today = datetime.today()

data6[((data6['운영현황'] == '휴지') & (pd.to_datetime(data6['휴지종료일자'], errors='coerce') > today))]
# Out:
#            시군구         어린이집명 어린이집유형구분 운영현황   우편번호  \
# 135    고양시일산동구       별바람어린이집       가정   휴지  10304
# 570    고양시일산서구  예꼬몬테소리스쿨어린이집       민간   휴지  10209
# 696    고양시일산서구        송이어린이집       가정   휴지  10219
# 953     고양시덕양구       자연숲어린이집       민간   휴지  10504
# 1101    고양시덕양구     푸른무지개어린이집       민간   휴지  10511
# ...        ...           ...      ...  ...    ...
# 17059      광주시       애플비어린이집       민간   휴지  12744
# 17290      광주시    양우좋은나무어린이집       가정   휴지  12774
# 17408      광주시     꼬마숲동현어린이집       민간   휴지  12768
# 17548      여주시        알곡어린이집       민간   휴지  12607
# 17662      양평군       꾸러기어린이집       민간   휴지  12581
#
#                                                     주소  보육실면적  보육교직원수  현원수  \
# 135                  경기도 고양시 일산동구 은행마을로 16 관리동 별바람어린이집     79       0    0
# 570                            경기도 고양시 일산서구 가좌4로 6-10     166       0    0
# 696    경기도 고양시 일산서구 대화2로 68 204동 102호(대화동, 대화마을2단지아파트)     60       0    0
# ...

# %%
# '운영현황'이 '휴지'이고 '휴지종료일자'가 오늘 이후인 행을 삭제
data6 = data6[~((data6['운영현황'] == '휴지') & (pd.to_datetime(data6['휴지종료일자'], errors='coerce') > today))]
data6
# Out:
#            시군구       어린이집명 어린이집유형구분 운영현황   우편번호  \
# 3       고양시덕양구      솔비어린이집       가정   정상  10530
# 5      고양시일산서구      미소어린이집       가정   정상  10376
# 7       고양시덕양구   신임마누엘어린이집       민간   정상  10275
# 9          양주시      신우어린이집       가정   정상  11444
# 22     고양시일산동구  고양시립저현어린이집      국공립   정상  10323
# ...        ...         ...      ...  ...    ...
# 17718      양평군    가온써밋어린이집       민간   정상  12553
# 17719      양평군  해피키즈어반어린이집       민간   정상  12562
# 17720      양평군    한라소담어린이집      국공립   정상  12551
# 17721      양평군    한라별숲어린이집      국공립   정상  12551
# 17722      양평군   반도유보라어린이집      국공립   정상  12519
#
#                                                       주소  보육실면적  보육교직원수  현원수  \
# 3          경기도 고양시 덕양구 소만로 19 612동 102호(행신동, 소만마을6단지아파트)     45       7   14
# 5      경기도 고양시 일산서구 대산로 249 106동 102호(대화동, 성저마을동익1단지아파트)     54       5   15
# 7                           경기도 고양시 덕양구 혜음로13번길 34 (고양동)    689      29   71
# ...

# %%
 data6[data6['운영현황'] == '휴지']
# Out:
#         시군구         어린이집명 어린이집유형구분 운영현황   우편번호  \
# 1654   의정부시      아이사랑어린이집       민간   휴지  11613
# 1718   의정부시      행복누리어린이집       가정   휴지  11803
# 2225   남양주시     신명곰누리어린이집       가정   휴지  12226
# 2239   남양주시      도담도담어린이집       가정   휴지  12186
# 2241   남양주시         꿈어린이집       가정   휴지  12222
# ...     ...           ...      ...  ...    ...
# 15713   화성시  사회복지법인조암어린이집   사회복지법인   휴지  18562
# 16132   화성시        해랑어린이집       가정   휴지  18328
# 17232   광주시        혜윤어린이집       가정   휴지  12762
# 17315   광주시      성신아이어린이집       가정   휴지  12765
# 17546   여주시    에코비글로벌어린이집       민간   휴지  12604
#
#                                                       주소  보육실면적  보육교직원수  현원수  \
# 1654                             경기도 의정부시 비우로92번길 13-12     313       0    0
# 1718           경기도 의정부시 용현로 111 102동 106호(민락동,송산푸르지오아파트)     84       0    0
# 2225   경기도 남양주시 의안로 155 1802동 101호(평내동, 평내마을신명스카이뷰18단...     65       0    0
# 2239        경기도 남양주시 화도읍 수레로1233번길 11 101동 101호(창현리, 경향)     87       1    0
# ...

# %%
data6 = data6.drop(['휴지종료일자'], axis=1)
data6
# Out:
#            시군구       어린이집명 어린이집유형구분 운영현황   우편번호  \
# 3       고양시덕양구      솔비어린이집       가정   정상  10530
# 5      고양시일산서구      미소어린이집       가정   정상  10376
# 7       고양시덕양구   신임마누엘어린이집       민간   정상  10275
# 9          양주시      신우어린이집       가정   정상  11444
# 22     고양시일산동구  고양시립저현어린이집      국공립   정상  10323
# ...        ...         ...      ...  ...    ...
# 17718      양평군    가온써밋어린이집       민간   정상  12553
# 17719      양평군  해피키즈어반어린이집       민간   정상  12562
# 17720      양평군    한라소담어린이집      국공립   정상  12551
# 17721      양평군    한라별숲어린이집      국공립   정상  12551
# 17722      양평군   반도유보라어린이집      국공립   정상  12519
#
#                                                       주소  보육실면적  보육교직원수  현원수  \
# 3          경기도 고양시 덕양구 소만로 19 612동 102호(행신동, 소만마을6단지아파트)     45       7   14
# 5      경기도 고양시 일산서구 대산로 249 106동 102호(대화동, 성저마을동익1단지아파트)     54       5   15
# 7                           경기도 고양시 덕양구 혜음로13번길 34 (고양동)    689      29   71
# ...

# %%
data6['시군구'].unique()
# Out:
# array(['고양시덕양구', '고양시일산서구', '양주시', '고양시일산동구', '의정부시', '남양주시', '파주시',
#        '구리시', '포천시', '동두천시', '가평군', '연천군', '수원시', '수원시장안구', '용인시수지구',
#        '수원시권선구', '수원시팔달구', '수원시영통구', '성남시분당구', '성남시수정구', '성남시중원구', '안양시',
#        '안양시동안구', '안양시만안구', '부천시', '부천시원미구', '부천시오정구', '부천시소사구', '광명시',
#        '평택시', '안산시', '안산시상록구', '안산시단원구', '과천시', '오산시', '시흥시', '군포시',
#        '의왕시', '하남시', '용인시', '용인시처인구', '용인시기흥구', '이천시', '안성시', '김포시',
#        '화성시', '광주시', '여주시', '양평군'], dtype=object)

# %%
data6['운영현황'].unique()
# Out:
# array(['정상', '재개', '휴지'], dtype=object)

# %%
data6.head(2)
# Out:
#        시군구   어린이집명 어린이집유형구분 운영현황   우편번호  \
# 3   고양시덕양구  솔비어린이집       가정   정상  10530
# 5  고양시일산서구  미소어린이집       가정   정상  10376
#
#                                                   주소  보육실면적  보육교직원수  현원수  \
# 3      경기도 고양시 덕양구 소만로 19 612동 102호(행신동, 소만마을6단지아파트)     45       7   14
# 5  경기도 고양시 일산서구 대산로 249 106동 102호(대화동, 성저마을동익1단지아파트)     54       5   15
#
#           위도          경도 통학차량운영여부
# 3  37.610684  126.836452       운영
# 5  37.679268  126.750533      미운영

# %%
data6.isna().sum()
# Out:
# 시군구          0
# 어린이집명        0
# 어린이집유형구분     0
# 운영현황         0
# 우편번호         0
# 주소           0
# 보육실면적        0
# 보육교직원수       0
# 현원수          0
# 위도           1
# 경도           1
# 통학차량운영여부    32
# dtype: int64

# %%
data6.to_csv("C:/fintech_service/Data/프로젝트/어린이집현황_전처리.csv", index=False)
